# %% [markdown]
# # Deep learning programming I-A: Regression
# Felix Wiewel, Institute of Signal Processing and System Theory, University of Stuttgart, 24.04.2020
#
# ## Introduction
# This programming exercise is the first of a series of exercises, which are intended as a supplement to the theoretical part of the Deep Learning course offered by the ISS. The goal is to introduce you to basic tasks and applications of methods you have encountered in the lecture. After completing the exercise you should be familiar with the basic ideas and one, possibly simple, way of solving the respective task. It is worth mentioning that most of the tasks can be solved in many different, not necessarily deep learning based, ways and the solution presented here is just one of them.
#
# ## Regression
#
# In this exercise we consider the problem of regression, where we are interested in modeling a functional dependence between different variables with, possibly noisy, observations of input-output pairs. Mathematically such a dependence can be formulated as
#
# $\mathbf{y}=f(\mathbf{x})+\boldsymbol{\epsilon}$,
#
# where $\mathbf{y}\in\mathbb{R}^{M}$ and $\mathbf{x}\in\mathbb{R}^{N}$ are the input and output observations, $f:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ is the function mapping inputs to outputs and $\boldsymbol{\epsilon}\in\mathbb{R}^{M}$ is a random vector, which models noise in our observations. Note that this assumes additive noise that only acts on the output and not on the input variable, which might not be true in all practical applications but is a reasonable approximation. For regression we are now interested in estimating the functional relationship $f$ between the inputs and outputs. This can be done in many different ways, not just with neural networks, but for this exercise we focus on approximating this relationship with a neural network $g_{\boldsymbol{\theta}}:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ with parameter vector $\boldsymbol{\theta}$. The task is now to choose the parameters of the neural network in a way that results in a "good" approximation of $f$ with $g_{\boldsymbol{\theta}}$.
#
# In order to quantify how "good" our neural network can approximate $f$, we adopt a probabilistic view. For this we make the assumption that the noise $\boldsymbol{\epsilon}$ is a random vector drawn from a known dustribution, which enables us to derive a suitable cost function for training our neural network and also for quantifying a "good" approximation.
#
# ### Mathematical formulation
# If we assume that the noise $\boldsymbol{\epsilon}$ is drawn from a gaussian distribution, e.g. $\boldsymbol{\epsilon}\sim\mathcal{N}(\mathbf{0},\sigma^{2}\mathbf{I})$, we can use
#
# $\mathbf{y}=g_{\boldsymbol{\theta}}(\mathbf{x})+\boldsymbol{\epsilon}\Rightarrow \mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})=\boldsymbol{\epsilon}$
#
# to derive a log likelihood. Since the probability density function (pdf) of a multivariate normal distribution is given by
#
# $p(\mathbf{x})=\dfrac{1}{\sqrt{(2\pi)^{D}\vert\mathbf{C}\vert}}\mathrm{e}^{-\dfrac{1}{2}(\mathbf{x}-\boldsymbol{\mu})\mathbf{C}^{-1}(\mathbf{x}-\boldsymbol{\mu})^{T}}$,
#
# we get
#
# $\ln{p(\boldsymbol{\epsilon})}=\ln{\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}}}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$.
#
# Replacing $\boldsymbol{\epsilon}$ by $\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})$ yields the log likelihood for one particular input-output pair:
#
# $\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})=\ln {p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$
#
# This log likelihood measures how likely the input-output pair is and we can use it to train our neural network. For this we maximize the expected log likelihood over all input-output pairs under the assumption that the noise is idependent and identically distributed (i.i.d.) over all input-output pairs. This corresponds to finding the parameters $\boldsymbol{\theta}^{\star}$ of our neural network, which maximize the the expected probability for observing the corresponding input-output pairs. Mathematically the optimal parameters for our neural network are given by
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[-\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}\right]\approx\arg\min_{\boldsymbol{\theta}}\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where all terms, which are independent of $\boldsymbol{\theta}$, are ignored and the expectation operator is approximated by the mean over all $N_{D}$ input-output pairs. In other words we are maximizing the log likelihood by minimizing the mean squared error loss over all input-output pairs in our dataset, hence this approach is called Maximum Likelihood (ML) estimation. For solving this optimization problem and obtaining the optimal network parameters, stochastic gradient descent (SGD) or one of it's many variants is typically used.
#
# It is worth noting, that choosing different distributions for the noise $\boldsymbol{\epsilon}$ leads to different log likelihoods and therefore different cost functions for training the neural network. Another commonly used distribution for modelling the noise in regression tasks is the laplace distribution. Deriving the log likelihood and the corresponding costfunction leads to the mean absolute error, which is given by the $l_{1}$-norm of the difference between observations predictions of the neural network. This cost function is considered more robust against outliers since these have less influence on the averall loss compared to the mean squared error.
#
# ###  Implementation
#
# In the following we consider a simple regression task, implement a neural network and train it based on the mathematical fomrulation above. For this we first need to create a set of input-output pairs, which then needs to be partitioned into a training, validation and test set. We also define some constants to be used for partitioning the data and the hyperparameters for our neural network.
#
# But before we can start, we need to import the necessary packages tensorflow, numpy and matplotlib.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Next we define our constants and set the random seeds of tensorflow and numpy in order to get reproducable results.

# %%
N_train_samples = 600
N_validation_samples = 100
N_test_samples = 100
N_samples = N_train_samples + N_validation_samples + N_test_samples
noise_sig = 0.1
N_epochs = 150
batch_size = 8
learning_rate = 0.01

tf.random.set_seed(0)
np.random.seed(0)

# %% [markdown]
# We create $600$ training samples, $100$ validation samples to optimize our hyperparameters and $100$ test samples, which are used to check if our model can generalize to unseen data. Furthermore we set the level of noise added to the observations. For training the model we plan to train it for $150$ epochs with a batch size of $8$ and a learning rate of $0.01$. Next we create the actual input-output pairs $\mathbf{x},\mathbf{y}$ for which we want to learn the regression model and plot them. In this simple example we choose scalar inputs as well as output but in general $\mathbf{x}$ and $\mathbf{y}$ can be vectors.

# %%
x = np.linspace(0.0, 3.0, N_samples, dtype=np.float32)
y = np.expand_dims(np.sin(1.0+x*x) + noise_sig*np.random.randn(N_samples).astype(np.float32), axis=-1)
y_true = np.sin(1.0+x*x)

plt.plot(x, y)
plt.plot(x, y_true)
plt.grid(True)
plt.legend(["Observation", "Ground truth"])
plt.show()

# %% [markdown]
# With the input-output pairs created, your first task is now to partition the data in the training, validation and test sets. Keep in mind that we have created the data in a structured way, i.e. the input-output pairs are ordered. This means you need to shuffle the data before partitioning it.

# %%
""" Shuffle and partition the data set accordingly. you can use the predefined constants "N_train_samples", "N_validation_samples" and "N_test_samples". Use the variable names that are already in the below code 
to store the final shuffled and partitioned data. Hint: Shuffle the data and the labels in such a way that the pairing between an image and it's label is preserved."""
# Shuffle the data
sel_idx = np.arange(0, N_samples)
np.random.shuffle(sel_idx)
x_randomize = x[sel_idx]
y_randomize = y[sel_idx]

# Partition the data
x_train = x_randomize[0:(N_train_samples-1)]
y_train = y_randomize[0:(N_train_samples-1)]

x_validation = x_randomize[(N_train_samples):(N_train_samples+N_validation_samples-1)]
y_validation = y_randomize[(N_train_samples):(N_train_samples+N_validation_samples-1)]

x_test = x_randomize[(N_train_samples+N_validation_samples):(N_samples-1)]
y_test = y_randomize[(N_train_samples+N_validation_samples):(N_samples-1)]

# %% [markdown]
# In order to feed the data to our model, we will use the Dataset class provided by Tensorflow. This class is simple to use and provides all the functionality we need for shuffling, batching and feeding the data to our model. It is also tightly integrated into the Tensorflow framework, which makes it very performant. Performance is not an aspect we need to worry about in this exercise, but it is important in more demanding applications.
#
# In this exercise we instantiate a separate Dataset object for the training, validation and test data sets, where we shuffle and repeat just the training data set. Shuffling the validation and test data sets is not necessary, since we only evaluate the loss on those data sets and do not perform SGD on it. Please fill in the missing part of the code.

# %%
""" Create three tensorflow Dataset objects that can be used to feed the training test and validation data to a neural network. Hint: For the training data set use shuffling, batching with the size according to
the predefined constant "batch_size" and repeat the data set indefinetly. For the validation and test data sets no shuffling or batching is needed."""

#Shuffle , Batch and Repeat
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(N_train_samples).batch(batch_size).repeat()
validation_ds = tf.data.Dataset.from_tensor_slices((x_validation, y_validation))
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# In this exercise we will create a a simple neural network with two hidden layers containing $10$ neurons. For creating a model and keeping track of its weights a class called MyModel is used. When initializing an instance of this class the necessary variables are created and stored in a list called "trainable_variables". This makes it easy to get all trainable variables of the model. We also override the \__call__ method of this class in order to implement the forward pass of the neural network. This method should accept the inputs to the neural network and should return the result of the forward pass as an output. Please fill in the missing part of the code and select suitable activation functions for the different layers.

# %%
""" Implement a neural network with two hidden dense layers containing 10 neurons each. As an activation function use the tangens hyperbolicus (tf.nn.tanh()). Since we are not using Keras, we need to create and 
manage all the variables that we need ourselves. The varaibles are created in the constructor of our model class. Since we want to be able to just call the class with some inputs in order to make a prediction, 
we implement a __call__ method which computes the forward pass and returns the output of the network."""

class MyModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.normal([10,1], 0, 1, dtype = float))
        self.b0 = tf.Variable(tf.random.normal([10,1], 0, 1, dtype = float))
        self.W1 = tf.Variable(tf.random.normal([10,10], 0, 1, dtype = float))
        self.b1 = tf.Variable(tf.random.normal([10,1], 0, 1, dtype = float))
        self.W2 = tf.Variable(tf.random.normal([1,10], 0, 1, dtype = float))
        self.b2 = tf.Variable(tf.random.normal([1,1], 0, 1, dtype = float))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh(tf.matmul(self.W0, output)+self.b0)
        output = tf.nn.tanh(tf.matmul(self.W1, output)+self.b1)
        output = tf.nn.tanh(tf.matmul(self.W2, output)+self.b2)
        return output

# %% [markdown]
# Now after the model class is defined we can instantiate a MyModel object by running

# %%
mdl = MyModel()

# %% [markdown]
# We can now use the model to make predictions by calling it. In the following we predict on the inputs an plot the result.

# %%
""" We want to plot a prediction on the complete data set with a model before training. For this make a prediction on the variable "x". """
y_pred = tf.reshape(tf.map_fn(mdl, x), shape=[N_samples,]) # Compute a prediction on the variable "x"
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Since we have initialized the variables of the neural network randomly, it's prediction is also random. In order to fit the model we need to minimize the expected mean squared error over all input-ouput pairs in our training data set. For this we need to create a function, that performs a training step when provided with the model, an optimizer and a batch of input-ouput pairs.

# %%
""" For training we need to implement a function that executes one training step. Fill in the missing code pieces for this function."""
def train_step(model, optimizer, x, y):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model(x)# Compute a prediction with "model" on the input "x"
        loss_val = tf.math.reduce_mean(tf.math.squared_difference(y_pred,y))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
    grads = tape.gradient(loss_val, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# This function uses the GradientTape to record the operations for which gradients have to be calculated. In our case this is the forward pass through our model and the computation of the loss function. After these operations are recoded we can get their gradients and apply these through the use of an optimizer. Finally we return the loss value in order to print it.
#
# With the training step function defined we now need to choose a suitable optimizer. Tensorflow offers a wide variety of optimizers but in this exercise we will use the RMSprop optimizer.

# %%
opt = tf.optimizers.RMSprop(learning_rate)

# %% [markdown]
# We now have everything we need to start training the model. For this we repeatedly sample a batch of input-output pairs from our training data set and use the train_step function to minimize the loss function over this batch. We repeat this until we have iterated over the complete training data set once. After this we compute the loss on the validation data set, print it and repeat with another epoch until we have reached $N\_epochs$ epochs.

# %%
""" We can now use the train_step function to perform the training. Fill in the missing code parts."""
epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_ds:
    for x_t_batch, y_t_batch in zip(x_t, y_t):
      train_loss += train_step(mdl, opt, x_t_batch, y_t_batch)# Perform a training step with the model "mdl" and the optimizer "opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if (batch_size * train_iters == N_train_samples): # An epoch is completed
        validation_loss = 0.0
        for x_v, y_v in validation_ds:
            y_pred =  mdl(x_v) # Compute a prediction with "mdl" on the input "x_v"
            validation_loss += tf.reduce_mean(tf.math.squared_difference(y_pred,y_v))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 1.6633 Validation loss: 7.458
# Epoch: 1 Train loss: 0.98296 Validation loss: 8.7685
# Epoch: 2 Train loss: 0.86564 Validation loss: 3.9148
# Epoch: 3 Train loss: 0.75197 Validation loss: 4.8114
# Epoch: 4 Train loss: 0.6673 Validation loss: 4.9136
# Epoch: 5 Train loss: 0.65846 Validation loss: 3.0004
# Epoch: 6 Train loss: 0.62222 Validation loss: 3.2657
# Epoch: 7 Train loss: 0.62459 Validation loss: 2.8592
# Epoch: 8 Train loss: 0.62089 Validation loss: 3.2682
# Epoch: 9 Train loss: 0.57243 Validation loss: 8.751
# Epoch: 10 Train loss: 0.55685 Validation loss: 3.6792
# Epoch: 11 Train loss: 0.51896 Validation loss: 3.1692
# Epoch: 12 Train loss: 0.43279 Validation loss: 2.277
# Epoch: 13 Train loss: 0.40746 Validation loss: 2.7351
# Epoch: 14 Train loss: 0.38233 Validation loss: 2.2886
# Epoch: 15 Train loss: 0.36871 Validation loss: 2.4797
# Epoch: 16 Train loss: 0.3812 Validation loss: 2.0381
# Epoch: 17 Train loss: 0.3444 Validation loss: 2.9137
# Epoch: 18 Train loss: 0.32716 Validation loss: 3.5291
# Epoch: 19 Train loss: 0.32651 Validation loss: 2.0641
# Epoch: 20 Train loss: 0.35033 Validation loss: 2.0783
# Epoch: 21 Train loss: 0.32464 Validation loss: 3.6814
# Epoch: 22 Train loss: 0.34859 Validation loss: 1.6462
# Epoch: 23 Train loss: 0.34163 Validation loss: 4.3591
# Epoch: 24 Train loss: 0.3136 Validation loss: 2.6428
# Epoch: 25 Train loss: 0.3141 Validation loss: 2.7048
# Epoch: 26 Train loss: 0.30167 Validation loss: 2.9681
# Epoch: 27 Train loss: 0.31947 Validation loss: 2.2506
# Epoch: 28 Train loss: 0.30999 Validation loss: 9.9736
# Epoch: 29 Train loss: 0.28852 Validation loss: 2.9195
# Epoch: 30 Train loss: 0.31805 Validation loss: 1.3562
# Epoch: 31 Train loss: 0.29213 Validation loss: 3.5083
# Epoch: 32 Train loss: 0.29033 Validation loss: 2.4452
# Epoch: 33 Train loss: 0.29625 Validation loss: 1.9066
# Epoch: 34 Train loss: 0.28893 Validation loss: 2.286
# Epoch: 35 Train loss: 0.27774 Validation loss: 5.198
# Epoch: 36 Train loss: 0.27195 Validation loss: 1.6858
# Epoch: 37 Train loss: 0.29193 Validation loss: 2.1373
# Epoch: 38 Train loss: 0.29249 Validation loss: 1.7843
# Epoch: 39 Train loss: 0.27942 Validation loss: 3.168
# Epoch: 40 Train loss: 0.28752 Validation loss: 1.4884
# Epoch: 41 Train loss: 0.26255 Validation loss: 4.4442
# Epoch: 42 Train loss: 0.29329 Validation loss: 4.6365
# Epoch: 43 Train loss: 0.28587 Validation loss: 2.2696
# Epoch: 44 Train loss: 0.28594 Validation loss: 3.4816
# Epoch: 45 Train loss: 0.26225 Validation loss: 4.627
# Epoch: 46 Train loss: 0.29492 Validation loss: 4.3728
# Epoch: 47 Train loss: 0.26987 Validation loss: 3.9878
# Epoch: 48 Train loss: 0.26902 Validation loss: 2.7931
# Epoch: 49 Train loss: 0.27739 Validation loss: 1.6469
# Epoch: 50 Train loss: 0.29155 Validation loss: 1.3386
# Epoch: 51 Train loss: 0.28341 Validation loss: 1.4139
# Epoch: 52 Train loss: 0.25661 Validation loss: 5.1549
# Epoch: 53 Train loss: 0.28144 Validation loss: 2.0539
# Epoch: 54 Train loss: 0.26265 Validation loss: 4.2106
# Epoch: 55 Train loss: 0.27562 Validation loss: 2.228
# Epoch: 56 Train loss: 0.25568 Validation loss: 2.9876
# Epoch: 57 Train loss: 0.25675 Validation loss: 4.6756
# Epoch: 58 Train loss: 0.27141 Validation loss: 1.7307
# Epoch: 59 Train loss: 0.26357 Validation loss: 1.5471
# Epoch: 60 Train loss: 0.25208 Validation loss: 1.6881
# Epoch: 61 Train loss: 0.26734 Validation loss: 1.753
# Epoch: 62 Train loss: 0.27 Validation loss: 3.2472
# Epoch: 63 Train loss: 0.25803 Validation loss: 3.7489
# Epoch: 64 Train loss: 0.25618 Validation loss: 3.0519
# Epoch: 65 Train loss: 0.2523 Validation loss: 1.8891
# Epoch: 66 Train loss: 0.27216 Validation loss: 2.5059
# Epoch: 67 Train loss: 0.2561 Validation loss: 2.3718
# Epoch: 68 Train loss: 0.25128 Validation loss: 2.0104
# Epoch: 69 Train loss: 0.24344 Validation loss: 1.9412
# Epoch: 70 Train loss: 0.25576 Validation loss: 6.3187
# Epoch: 71 Train loss: 0.26812 Validation loss: 2.8242
# Epoch: 72 Train loss: 0.25106 Validation loss: 1.9437
# Epoch: 73 Train loss: 0.2493 Validation loss: 1.6078
# Epoch: 74 Train loss: 0.2371 Validation loss: 2.9083
# Epoch: 75 Train loss: 0.23559 Validation loss: 2.6086
# Epoch: 76 Train loss: 0.24015 Validation loss: 3.3688
# Epoch: 77 Train loss: 0.246 Validation loss: 1.3753
# Epoch: 78 Train loss: 0.2412 Validation loss: 1.6846
# Epoch: 79 Train loss: 0.23225 Validation loss: 1.8125
# Epoch: 80 Train loss: 0.23284 Validation loss: 1.4004
# Epoch: 81 Train loss: 0.24382 Validation loss: 3.0764
# Epoch: 82 Train loss: 0.22505 Validation loss: 1.6305
# Epoch: 83 Train loss: 0.24829 Validation loss: 1.7833
# Epoch: 84 Train loss: 0.22806 Validation loss: 3.5527
# Epoch: 85 Train loss: 0.22929 Validation loss: 2.8077
# Epoch: 86 Train loss: 0.24776 Validation loss: 1.5156
# Epoch: 87 Train loss: 0.22953 Validation loss: 2.2472
# Epoch: 88 Train loss: 0.22014 Validation loss: 2.8199
# Epoch: 89 Train loss: 0.23735 Validation loss: 2.211
# Epoch: 90 Train loss: 0.22916 Validation loss: 1.7962
# Epoch: 91 Train loss: 0.21583 Validation loss: 1.7953
# Epoch: 92 Train loss: 0.21826 Validation loss: 1.966
# Epoch: 93 Train loss: 0.23013 Validation loss: 1.6893
# Epoch: 94 Train loss: 0.21639 Validation loss: 2.5203
# Epoch: 95 Train loss: 0.20137 Validation loss: 1.8354
# Epoch: 96 Train loss: 0.21913 Validation loss: 2.3778
# Epoch: 97 Train loss: 0.21727 Validation loss: 2.4254
# Epoch: 98 Train loss: 0.21433 Validation loss: 2.01
# Epoch: 99 Train loss: 0.22279 Validation loss: 2.2009
# Epoch: 100 Train loss: 0.21006 Validation loss: 1.6447
# Epoch: 101 Train loss: 0.21489 Validation loss: 2.5885
# Epoch: 102 Train loss: 0.21017 Validation loss: 3.3484
# Epoch: 103 Train loss: 0.22684 Validation loss: 2.2151
# Epoch: 104 Train loss: 0.22814 Validation loss: 2.1299
# Epoch: 105 Train loss: 0.20795 Validation loss: 2.9124
# Epoch: 106 Train loss: 0.20897 Validation loss: 1.576
# Epoch: 107 Train loss: 0.22495 Validation loss: 1.691
# Epoch: 108 Train loss: 0.20508 Validation loss: 3.3381
# Epoch: 109 Train loss: 0.21436 Validation loss: 2.4068
# Epoch: 110 Train loss: 0.23012 Validation loss: 1.586
# Epoch: 111 Train loss: 0.21633 Validation loss: 1.7647
# Epoch: 112 Train loss: 0.21599 Validation loss: 1.7866
# Epoch: 113 Train loss: 0.20875 Validation loss: 1.5242
# Epoch: 114 Train loss: 0.2096 Validation loss: 1.4949
# Epoch: 115 Train loss: 0.21449 Validation loss: 1.7573
# Epoch: 116 Train loss: 0.20534 Validation loss: 3.1418
# Epoch: 117 Train loss: 0.21145 Validation loss: 1.6506
# Epoch: 118 Train loss: 0.21339 Validation loss: 6.129
# Epoch: 119 Train loss: 0.22005 Validation loss: 1.4381
# Epoch: 120 Train loss: 0.20422 Validation loss: 2.2484
# Epoch: 121 Train loss: 0.21561 Validation loss: 3.3327
# Epoch: 122 Train loss: 0.21549 Validation loss: 1.4554
# Epoch: 123 Train loss: 0.20606 Validation loss: 3.8101
# Epoch: 124 Train loss: 0.19543 Validation loss: 3.5344
# Epoch: 125 Train loss: 0.21674 Validation loss: 2.3086
# Epoch: 126 Train loss: 0.21477 Validation loss: 1.465
# Epoch: 127 Train loss: 0.20572 Validation loss: 1.9563
# Epoch: 128 Train loss: 0.19965 Validation loss: 1.4474
# Epoch: 129 Train loss: 0.19982 Validation loss: 1.3092
# Epoch: 130 Train loss: 0.20782 Validation loss: 1.5327
# Epoch: 131 Train loss: 0.21378 Validation loss: 1.2715
# Epoch: 132 Train loss: 0.2098 Validation loss: 2.071
# Epoch: 133 Train loss: 0.19806 Validation loss: 2.1948
# Epoch: 134 Train loss: 0.22169 Validation loss: 1.9653
# Epoch: 135 Train loss: 0.20735 Validation loss: 2.0674
# Epoch: 136 Train loss: 0.21424 Validation loss: 2.4493
# Epoch: 137 Train loss: 0.21499 Validation loss: 1.9184
# Epoch: 138 Train loss: 0.20244 Validation loss: 2.2172
# Epoch: 139 Train loss: 0.21861 Validation loss: 3.4375
# Epoch: 140 Train loss: 0.21429 Validation loss: 1.8882
# Epoch: 141 Train loss: 0.20952 Validation loss: 2.08
# Epoch: 142 Train loss: 0.21226 Validation loss: 2.0123
# Epoch: 143 Train loss: 0.20983 Validation loss: 1.8274
# Epoch: 144 Train loss: 0.19531 Validation loss: 2.4918
# Epoch: 145 Train loss: 0.20233 Validation loss: 2.2908
# Epoch: 146 Train loss: 0.21043 Validation loss: 2.2032
# Epoch: 147 Train loss: 0.20713 Validation loss: 2.2847
# Epoch: 148 Train loss: 0.21969 Validation loss: 2.7169
# Epoch: 149 Train loss: 0.19844 Validation loss: 1.3622

# %% [markdown]
# After completion of the training process we use the test data set to test the models generalization to unseen data.

# %%
for x_t, y_t in test_ds:
    y_pred = mdl(x_t)# Compute a prediction with "mdl" on the input "x_t"
    test_loss =  tf.reduce_mean(tf.math.squared_difference(y_pred,y_t))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_t"
print("Test loss: {:.5}".format(test_loss))
# Out:
# Test loss: 0.034847

# %% [markdown]
# After we have verified that our model achieves a similar loss on the test as on the validation and training data set, we can conclude that our model is not overfitting or underfitting and generalizes to unseen data. We can now predict on the inputs again and plot the results.

# %%
y_pred = tf.reshape(tf.map_fn(mdl, x), shape=[N_samples,])
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred)
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Now our model has learned to approximate the function mapping from the input to the output. The capability of neural networks to learn from input-ouput pairs alone and approximate an arbitrary function, see universal approximation theorem, can be very useful if the mapping between the input and output is too complex to be captured with model based approaches. But learning from input-ouput pairs alone implies that the model will only be able to make accurate predictions over input ranges it has seen during training. In order to demonstrate this we will predict on an interval that exeeds the $\left[0,3\right]$ interval the model was trained on, i.e. we will predict on the interval $\left[-2,5\right]$.

# %%
x_generalize = np.linspace(-2.0, 5.0, N_samples, dtype=np.float32)
y_generalize = np.sin(1.0+x_generalize*x_generalize) + noise_sig*np.random.randn(N_samples).astype(np.float32)
y_truey_generalize = np.sin(1.0+x_generalize*x_generalize)
y_pred = tf.reshape(tf.map_fn(mdl, x_generalize), shape=[N_samples,])
plt.plot(x_generalize, y_generalize)
plt.plot(x_generalize, y_truey_generalize)
plt.plot(x_generalize, y_pred)
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# As expected, the model is able to make farely accurate predictions on the interval it was trained on but makes unreliable predictions outside this interval.
#
# ### Regularization
# In this section we will explore the concept of regularization. As there is no theorem that can be used to determine the required size and structure of a neural network given a certain task, one has to find a suitable neural architecture by trial and error. This can result in choosing a architecture with a capacity that is higher than required for solving the given task and hence overfitting might occur. A common way to prevent large neural networks networks from overfitting is to employ some sort of regularization, e.g. weight norm penalty, dropout, early stopping and data augmentation. In this section we will focus on weight norm penalty as a regularization and derive a probabilistic interpretation for some of those.
#
# We start by restating the conditional probability of the output $\mathbf{y}$ given the input $\mathbf{x}$ and the networks parameters $\boldsymbol{\theta}$
#
# $p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})=\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}}$,
#
# which we used to derive the log likelihood. If we have some prior knowledge about the parameters of the neural network, which is given by a pdf $p(\boldsymbol{\theta})$ over the weights, we can use Bayes theorem to derive a posterior distribution
#
# $p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})=\dfrac{p(\boldsymbol{\theta},\mathbf{y}\vert\mathbf{x})}{p(\mathbf{y})}=\dfrac{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})p(\boldsymbol{\theta})}{p(\mathbf{y})}$
#
# where $p(\boldsymbol{\theta})$ is the  prior over the networks parameters. Similar to the derivation at the beginning of the exercise, we can use this posterior distribution to derive a cost function for training the neural network. In this case, however, we are not maximizing the log likelihood but the posterior distribution over the weights, hence this approach is called Maximum A Posteori (MAP) estimation of the parameters. Mathematically we can formulate this as
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\ln{p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})}\right]=\arg\max_{\boldsymbol{\theta}}\ln{p(\boldsymbol{\theta})}+\mathbb{E}\left[\ln{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}\right]$,
#
# where we used the fact that applying a strictly increasing function, e.g. $\ln{}$, does not change the position of the maximum of a cost function, ignored $p(\mathbf{y})$, since it is independent of the network parameters and dropped the expectation operator for $\ln{p(\boldsymbol{\theta})}$, since it is not depending on the random variable $\mathbf{x}$. Comparing the MAP estimate of the parameters with the ML estimate we derived above, shows that the only difference is the addition of $\ln{p(\boldsymbol{\theta})}$. This term is the regularization, i.e. the weight norm penalty. Depending on the distribution over $\boldsymbol{\theta}$ it can have different forms. If we choose a standard normal distribution, i.e. $\boldsymbol{\theta\sim\mathcal{N}(\mathbf{0},\mathbf{I})}$,  we get
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{2}^{2}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where we have made the same simplifications as for the ML estimation and also introduced the parameter $\lambda=\sigma^{2}$, which is used to control the strength of the regularization. This form of regularization is commonly known as $l_{2}$-norm or weight decay regularization. Choosing a prior where the weights follow an i.i.d laplacian distribution, i.e. $p(\boldsymbol{\theta})=\prod_{j}\dfrac{1}{2}\mathrm{e}^{\vert\theta_{j}\vert}$, leads to
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{1}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where the strength of the regularization is again controlled by $\lambda=\sigma^{2}$. This type of regularization is known as  $l_{1}$-norm and it has the property to induce sparsity in the parameters of the network.
#
# With this theoretical background on regularization we can now implement it and observe it's effects on the regression problem covered in this exercise. For this we will define a model with a high capacity and train it for a extended time to provoke overfitting. For this, we will increase the number of hidden neurons in both hidden layers to $100$ and $50$.

# %%
""" Implement a bigger model with again two hidden layers contatining 100 and 50 neurons. As an activation use the tangens hyperbolicus function where it is appropiate. """

class MyBigModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.normal([100,1], 0, 1, tf.float32))
        self.b0 = tf.Variable(tf.random.normal([100,1], 0, 1, tf.float32))
        self.W1 = tf.Variable(tf.random.normal([50,100], 0, 1, tf.float32))
        self.b1 = tf.Variable(tf.random.normal([50,1], 0, 1, tf.float32))
        self.W2 = tf.Variable(tf.random.normal([1,50], 0, 1, tf.float32))
        self.b2 = tf.Variable(tf.random.normal([1,1], 0, 1, tf.float32))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh(tf.matmul(self.W0, output)+self.b0)
        output = tf.nn.tanh(tf.matmul(self.W1, output)+self.b1)
        output = tf.nn.tanh(tf.matmul(self.W2, output)+self.b2)
        return output

# %% [markdown]
# After creating one instance of this class we can again train it on our data set. We will also create a new optimizer for training this bigger model, since some optimizers adapt the learning rates for individual parameters during a training process and we do not want to train our bigger model with learning rates adopted from an earlier training run.

# %%
big_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

""" For training we need to implement a function that executes one training step. Fill in the missing code pieces for this function."""
def train_step2(model, optimizer, x, y):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model(x)# Compute a prediction with "model" on the input "x"
        loss_val = tf.math.reduce_mean(tf.math.squared_difference(y_pred,y))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
    grads = tape.gradient(loss_val, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# Now we are ready to train this bigger model using the same training step and training loop. In order to provoke overfitting we also reduce the number of samples in the training data set a lot, increase the batch size and train for a more epochs.

# %%
""" Implement the training for the bigger model similar to the training of the small model before. """

N_train_samples_overfit = 30
N_epochs = 1000
batch_size = 30

sel_idx = np.arange(0, N_train_samples)
sel_idx = np.random.choice(sel_idx, N_train_samples_overfit)
x_train_overfit = x_train[sel_idx]
y_train_overfit = y_train[sel_idx]

train_overfit_ds = tf.data.Dataset.from_tensor_slices((x_train_overfit, y_train_overfit)).shuffle(N_train_samples_overfit).batch(batch_size).repeat(500)

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    for x_t_batch, y_t_batch in zip(x_t, y_t):
        train_loss += train_step2(big_mdl, big_opt, x_t_batch, y_t_batch)# Perform a training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if (batch_size * train_iters == N_train_samples_overfit):# An epoch is completed
        validation_loss = 0
        for x_v, y_v in validation_ds:
            y_pred = big_mdl(x_v)# Compute a prediction with "big_mdl" on the input "x_v"
            validation_loss += tf.reduce_mean(tf.math.squared_difference(y_pred,y_v))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 35.618 Validation loss: 75.265
# Epoch: 1 Train loss: 18.584 Validation loss: 76.305
# Epoch: 2 Train loss: 33.973 Validation loss: 76.305
# Epoch: 3 Train loss: 33.972 Validation loss: 76.304
# Epoch: 4 Train loss: 33.972 Validation loss: 76.303
# Epoch: 5 Train loss: 33.972 Validation loss: 76.303
# Epoch: 6 Train loss: 33.972 Validation loss: 76.302
# Epoch: 7 Train loss: 33.971 Validation loss: 76.301
# Epoch: 8 Train loss: 33.971 Validation loss: 76.3
# Epoch: 9 Train loss: 33.971 Validation loss: 76.299
# Epoch: 10 Train loss: 33.971 Validation loss: 76.298
# Epoch: 11 Train loss: 33.97 Validation loss: 76.296
# Epoch: 12 Train loss: 33.97 Validation loss: 76.295
# Epoch: 13 Train loss: 33.969 Validation loss: 76.294
# Epoch: 14 Train loss: 33.969 Validation loss: 76.292
# Epoch: 15 Train loss: 33.969 Validation loss: 76.29
# Epoch: 16 Train loss: 33.968 Validation loss: 76.288
# Epoch: 17 Train loss: 33.967 Validation loss: 76.285
# Epoch: 18 Train loss: 33.967 Validation loss: 76.283
# Epoch: 19 Train loss: 33.966 Validation loss: 76.279
# Epoch: 20 Train loss: 33.965 Validation loss: 76.276
# Epoch: 21 Train loss: 33.964 Validation loss: 76.272
# Epoch: 22 Train loss: 33.963 Validation loss: 76.267
# Epoch: 23 Train loss: 33.962 Validation loss: 76.261
# Epoch: 24 Train loss: 33.96 Validation loss: 76.254
# Epoch: 25 Train loss: 33.958 Validation loss: 76.246
# Epoch: 26 Train loss: 33.956 Validation loss: 76.236
# Epoch: 27 Train loss: 33.953 Validation loss: 76.224
# Epoch: 28 Train loss: 33.95 Validation loss: 76.208
# Epoch: 29 Train loss: 33.946 Validation loss: 76.189
# Epoch: 30 Train loss: 33.941 Validation loss: 76.163
# Epoch: 31 Train loss: 33.935 Validation loss: 76.129
# Epoch: 32 Train loss: 33.927 Validation loss: 76.083
# Epoch: 33 Train loss: 33.917 Validation loss: 76.015
# Epoch: 34 Train loss: 33.903 Validation loss: 75.918
# Epoch: 35 Train loss: 33.885 Validation loss: 75.775
# Epoch: 36 Train loss: 33.861 Validation loss: 75.557
# Epoch: 37 Train loss: 33.824 Validation loss: 75.078
# Epoch: 38 Train loss: 33.718 Validation loss: 73.585
# Epoch: 39 Train loss: 32.946 Validation loss: 26.171
# Epoch: 40 Train loss: 7.6969 Validation loss: 11.395
# Epoch: 41 Train loss: 15.495 Validation loss: 64.344
# Epoch: 42 Train loss: 16.952 Validation loss: 34.999
# Epoch: 43 Train loss: 7.069 Validation loss: 10.95
# Epoch: 44 Train loss: 8.956 Validation loss: 19.859
# Epoch: 45 Train loss: 4.9414 Validation loss: 4.4557
# Epoch: 46 Train loss: 2.5483 Validation loss: 4.0123
# Epoch: 47 Train loss: 2.7519 Validation loss: 4.6134
# Epoch: 48 Train loss: 1.9547 Validation loss: 12.541
# Epoch: 49 Train loss: 2.3197 Validation loss: 5.5957
# Epoch: 50 Train loss: 1.9226 Validation loss: 3.7571
# Epoch: 51 Train loss: 7.0751 Validation loss: 24.402
# Epoch: 52 Train loss: 3.9909 Validation loss: 6.639
# Epoch: 53 Train loss: 2.6215 Validation loss: 4.8341
# Epoch: 54 Train loss: 1.4137 Validation loss: 11.691
# Epoch: 55 Train loss: 7.3164 Validation loss: 5.7856
# Epoch: 56 Train loss: 3.1987 Validation loss: 4.6434
# Epoch: 57 Train loss: 1.8563 Validation loss: 13.647
# Epoch: 58 Train loss: 6.0842 Validation loss: 4.5447
# Epoch: 59 Train loss: 5.3453 Validation loss: 6.2492
# Epoch: 60 Train loss: 5.5288 Validation loss: 7.7222
# Epoch: 61 Train loss: 1.7957 Validation loss: 4.0072
# Epoch: 62 Train loss: 1.6229 Validation loss: 3.8361
# Epoch: 63 Train loss: 1.3559 Validation loss: 3.8551
# Epoch: 64 Train loss: 1.2521 Validation loss: 4.4412
# Epoch: 65 Train loss: 1.2403 Validation loss: 5.4731
# Epoch: 66 Train loss: 1.5576 Validation loss: 3.9506
# Epoch: 67 Train loss: 1.2261 Validation loss: 4.626
# Epoch: 68 Train loss: 1.2638 Validation loss: 3.6893
# Epoch: 69 Train loss: 1.277 Validation loss: 4.288
# Epoch: 70 Train loss: 1.2562 Validation loss: 4.7865
# Epoch: 71 Train loss: 1.3214 Validation loss: 3.6798
# Epoch: 72 Train loss: 1.2501 Validation loss: 3.8344
# Epoch: 73 Train loss: 1.1586 Validation loss: 4.5518
# Epoch: 74 Train loss: 1.3992 Validation loss: 3.9279
# Epoch: 75 Train loss: 1.6344 Validation loss: 3.6765
# Epoch: 76 Train loss: 1.1917 Validation loss: 3.9421
# Epoch: 77 Train loss: 2.2337 Validation loss: 3.8083
# Epoch: 78 Train loss: 1.1545 Validation loss: 3.8207
# Epoch: 79 Train loss: 1.3144 Validation loss: 3.9957
# Epoch: 80 Train loss: 1.4189 Validation loss: 4.5586
# Epoch: 81 Train loss: 1.2478 Validation loss: 3.8217
# Epoch: 82 Train loss: 1.1826 Validation loss: 4.1038
# Epoch: 83 Train loss: 1.34 Validation loss: 3.7085
# Epoch: 84 Train loss: 1.1095 Validation loss: 4.0254
# Epoch: 85 Train loss: 1.2037 Validation loss: 3.8584
# Epoch: 86 Train loss: 1.309 Validation loss: 3.6887
# Epoch: 87 Train loss: 1.2125 Validation loss: 4.0693
# Epoch: 88 Train loss: 1.2584 Validation loss: 3.878
# Epoch: 89 Train loss: 1.1506 Validation loss: 3.9691
# Epoch: 90 Train loss: 1.2803 Validation loss: 3.751
# Epoch: 91 Train loss: 1.1847 Validation loss: 3.6982
# Epoch: 92 Train loss: 1.2315 Validation loss: 6.6766
# Epoch: 93 Train loss: 1.7688 Validation loss: 3.8338
# Epoch: 94 Train loss: 1.7856 Validation loss: 3.8733
# Epoch: 95 Train loss: 1.1311 Validation loss: 4.2023
# Epoch: 96 Train loss: 1.3836 Validation loss: 3.7131
# Epoch: 97 Train loss: 1.4065 Validation loss: 6.0759
# Epoch: 98 Train loss: 1.6765 Validation loss: 4.0839
# Epoch: 99 Train loss: 1.42 Validation loss: 3.7295
# Epoch: 100 Train loss: 1.114 Validation loss: 3.6733
# Epoch: 101 Train loss: 1.1391 Validation loss: 3.6969
# Epoch: 102 Train loss: 1.0916 Validation loss: 3.8071
# Epoch: 103 Train loss: 1.2772 Validation loss: 3.7481
# Epoch: 104 Train loss: 1.1665 Validation loss: 3.8058
# Epoch: 105 Train loss: 1.3688 Validation loss: 3.9541
# Epoch: 106 Train loss: 1.5785 Validation loss: 3.802
# Epoch: 107 Train loss: 1.1898 Validation loss: 3.8542
# Epoch: 108 Train loss: 1.3485 Validation loss: 4.6308
# Epoch: 109 Train loss: 1.6779 Validation loss: 3.8684
# Epoch: 110 Train loss: 1.4054 Validation loss: 3.7715
# Epoch: 111 Train loss: 1.3043 Validation loss: 3.687
# Epoch: 112 Train loss: 1.2729 Validation loss: 3.9616
# Epoch: 113 Train loss: 1.2407 Validation loss: 3.7385
# Epoch: 114 Train loss: 1.5144 Validation loss: 4.3752
# Epoch: 115 Train loss: 1.1097 Validation loss: 3.7784
# Epoch: 116 Train loss: 1.2261 Validation loss: 3.6963
# Epoch: 117 Train loss: 1.2835 Validation loss: 6.6445
# Epoch: 118 Train loss: 1.2276 Validation loss: 3.8476
# Epoch: 119 Train loss: 1.1219 Validation loss: 3.7431
# Epoch: 120 Train loss: 1.2906 Validation loss: 3.8129
# Epoch: 121 Train loss: 1.1815 Validation loss: 4.0872
# Epoch: 122 Train loss: 1.1944 Validation loss: 5.292
# Epoch: 123 Train loss: 1.7256 Validation loss: 3.8608
# Epoch: 124 Train loss: 1.1265 Validation loss: 3.8283
# Epoch: 125 Train loss: 1.3031 Validation loss: 4.9236
# Epoch: 126 Train loss: 2.1402 Validation loss: 3.7086
# Epoch: 127 Train loss: 1.1435 Validation loss: 4.1151
# Epoch: 128 Train loss: 1.1116 Validation loss: 3.7192
# Epoch: 129 Train loss: 1.1735 Validation loss: 3.8709
# Epoch: 130 Train loss: 1.2124 Validation loss: 3.8204
# Epoch: 131 Train loss: 1.6247 Validation loss: 4.6864
# Epoch: 132 Train loss: 1.4067 Validation loss: 3.6917
# Epoch: 133 Train loss: 1.3346 Validation loss: 3.9437
# Epoch: 134 Train loss: 1.3477 Validation loss: 3.9941
# Epoch: 135 Train loss: 1.266 Validation loss: 3.947
# Epoch: 136 Train loss: 1.1826 Validation loss: 3.8756
# Epoch: 137 Train loss: 1.1534 Validation loss: 3.6781
# Epoch: 138 Train loss: 1.1179 Validation loss: 3.8106
# Epoch: 139 Train loss: 1.2531 Validation loss: 3.8457
# Epoch: 140 Train loss: 1.3767 Validation loss: 3.8155
# Epoch: 141 Train loss: 1.1647 Validation loss: 4.2664
# Epoch: 142 Train loss: 1.0882 Validation loss: 3.9623
# Epoch: 143 Train loss: 1.4185 Validation loss: 4.0197
# Epoch: 144 Train loss: 1.2659 Validation loss: 4.172
# Epoch: 145 Train loss: 1.4343 Validation loss: 4.129
# Epoch: 146 Train loss: 1.2656 Validation loss: 3.8466
# Epoch: 147 Train loss: 1.2901 Validation loss: 3.9774
# Epoch: 148 Train loss: 1.073 Validation loss: 3.7652
# Epoch: 149 Train loss: 1.1887 Validation loss: 4.275
# Epoch: 150 Train loss: 1.3274 Validation loss: 4.1027
# Epoch: 151 Train loss: 1.0795 Validation loss: 3.838
# Epoch: 152 Train loss: 1.0692 Validation loss: 3.7483
# Epoch: 153 Train loss: 1.4103 Validation loss: 4.3307
# Epoch: 154 Train loss: 1.1392 Validation loss: 3.8246
# Epoch: 155 Train loss: 1.0392 Validation loss: 3.7278
# Epoch: 156 Train loss: 1.0586 Validation loss: 3.7905
# Epoch: 157 Train loss: 1.1857 Validation loss: 4.2277
# Epoch: 158 Train loss: 1.2472 Validation loss: 3.9908
# Epoch: 159 Train loss: 1.2475 Validation loss: 4.2473
# Epoch: 160 Train loss: 1.1939 Validation loss: 4.1362
# Epoch: 161 Train loss: 1.1014 Validation loss: 4.0506
# Epoch: 162 Train loss: 1.1554 Validation loss: 3.6898
# Epoch: 163 Train loss: 1.1916 Validation loss: 3.7264
# Epoch: 164 Train loss: 1.1341 Validation loss: 4.1498
# Epoch: 165 Train loss: 1.0861 Validation loss: 3.9409
# Epoch: 166 Train loss: 1.3171 Validation loss: 4.1172
# Epoch: 167 Train loss: 1.1917 Validation loss: 4.1548
# Epoch: 168 Train loss: 1.5965 Validation loss: 3.9364
# Epoch: 169 Train loss: 1.1338 Validation loss: 3.8091
# Epoch: 170 Train loss: 1.2931 Validation loss: 3.9121
# Epoch: 171 Train loss: 1.143 Validation loss: 3.9792
# Epoch: 172 Train loss: 1.0956 Validation loss: 3.8744
# Epoch: 173 Train loss: 1.0711 Validation loss: 3.7853
# Epoch: 174 Train loss: 1.4227 Validation loss: 3.7447
# Epoch: 175 Train loss: 1.0676 Validation loss: 3.758
# Epoch: 176 Train loss: 1.1001 Validation loss: 3.9328
# Epoch: 177 Train loss: 1.1428 Validation loss: 3.7094
# Epoch: 178 Train loss: 1.2135 Validation loss: 3.8727
# Epoch: 179 Train loss: 1.1458 Validation loss: 3.7588
# Epoch: 180 Train loss: 1.1296 Validation loss: 3.9855
# Epoch: 181 Train loss: 1.0756 Validation loss: 3.8632
# Epoch: 182 Train loss: 1.1668 Validation loss: 4.0539
# Epoch: 183 Train loss: 1.0859 Validation loss: 3.8679
# Epoch: 184 Train loss: 1.1508 Validation loss: 3.6991
# Epoch: 185 Train loss: 1.2215 Validation loss: 3.8933
# Epoch: 186 Train loss: 1.0995 Validation loss: 4.3238
# Epoch: 187 Train loss: 1.6614 Validation loss: 3.9446
# Epoch: 188 Train loss: 1.1192 Validation loss: 3.8387
# Epoch: 189 Train loss: 1.0845 Validation loss: 3.8282
# Epoch: 190 Train loss: 1.0952 Validation loss: 3.6723
# Epoch: 191 Train loss: 1.1016 Validation loss: 3.9219
# Epoch: 192 Train loss: 1.2236 Validation loss: 3.7933
# Epoch: 193 Train loss: 1.1671 Validation loss: 3.9101
# Epoch: 194 Train loss: 1.2308 Validation loss: 3.794
# Epoch: 195 Train loss: 1.1195 Validation loss: 5.0394
# Epoch: 196 Train loss: 1.1027 Validation loss: 4.3573
# Epoch: 197 Train loss: 1.1488 Validation loss: 3.9017
# Epoch: 198 Train loss: 1.1573 Validation loss: 4.0017
# Epoch: 199 Train loss: 1.2174 Validation loss: 4.5424
# Epoch: 200 Train loss: 1.3306 Validation loss: 3.6593
# Epoch: 201 Train loss: 1.1025 Validation loss: 3.8969
# Epoch: 202 Train loss: 1.2339 Validation loss: 3.7644
# Epoch: 203 Train loss: 1.1359 Validation loss: 3.867
# Epoch: 204 Train loss: 1.1567 Validation loss: 4.0426
# Epoch: 205 Train loss: 1.1649 Validation loss: 4.7918
# Epoch: 206 Train loss: 1.3951 Validation loss: 4.3872
# Epoch: 207 Train loss: 1.4331 Validation loss: 3.7988
# Epoch: 208 Train loss: 1.0922 Validation loss: 3.7651
# Epoch: 209 Train loss: 1.1161 Validation loss: 4.0038
# Epoch: 210 Train loss: 1.0858 Validation loss: 4.0693
# Epoch: 211 Train loss: 1.1217 Validation loss: 4.3614
# Epoch: 212 Train loss: 1.1138 Validation loss: 3.8751
# Epoch: 213 Train loss: 1.2374 Validation loss: 3.7708
# Epoch: 214 Train loss: 1.9517 Validation loss: 4.5249
# Epoch: 215 Train loss: 1.3196 Validation loss: 3.7098
# Epoch: 216 Train loss: 1.1149 Validation loss: 3.9717
# Epoch: 217 Train loss: 1.1593 Validation loss: 3.7938
# Epoch: 218 Train loss: 1.1016 Validation loss: 3.9245
# Epoch: 219 Train loss: 1.1705 Validation loss: 4.0134
# Epoch: 220 Train loss: 1.2194 Validation loss: 3.9689
# Epoch: 221 Train loss: 1.0243 Validation loss: 3.7543
# Epoch: 222 Train loss: 1.3354 Validation loss: 3.9309
# Epoch: 223 Train loss: 1.6815 Validation loss: 3.7849
# Epoch: 224 Train loss: 1.352 Validation loss: 3.7869
# Epoch: 225 Train loss: 1.2217 Validation loss: 3.8203
# Epoch: 226 Train loss: 1.1436 Validation loss: 4.1507
# Epoch: 227 Train loss: 1.2566 Validation loss: 3.6689
# Epoch: 228 Train loss: 1.2821 Validation loss: 3.7314
# Epoch: 229 Train loss: 1.1165 Validation loss: 3.7978
# Epoch: 230 Train loss: 1.1012 Validation loss: 3.9695
# Epoch: 231 Train loss: 1.0666 Validation loss: 3.9803
# Epoch: 232 Train loss: 1.0625 Validation loss: 4.3439
# Epoch: 233 Train loss: 1.1428 Validation loss: 4.1858
# Epoch: 234 Train loss: 1.6616 Validation loss: 3.757
# Epoch: 235 Train loss: 1.4763 Validation loss: 4.2799
# Epoch: 236 Train loss: 1.3158 Validation loss: 4.0585
# Epoch: 237 Train loss: 1.1254 Validation loss: 3.769
# Epoch: 238 Train loss: 1.2549 Validation loss: 4.6331
# Epoch: 239 Train loss: 1.2541 Validation loss: 3.6798
# Epoch: 240 Train loss: 1.0424 Validation loss: 5.002
# Epoch: 241 Train loss: 1.3399 Validation loss: 4.259
# Epoch: 242 Train loss: 1.1378 Validation loss: 3.9317
# Epoch: 243 Train loss: 1.3336 Validation loss: 4.8635
# Epoch: 244 Train loss: 1.599 Validation loss: 6.9935
# Epoch: 245 Train loss: 1.4663 Validation loss: 3.5803
# Epoch: 246 Train loss: 1.1138 Validation loss: 3.6828
# Epoch: 247 Train loss: 1.032 Validation loss: 4.2031
# Epoch: 248 Train loss: 1.1693 Validation loss: 3.8435
# Epoch: 249 Train loss: 1.1392 Validation loss: 4.0932
# Epoch: 250 Train loss: 1.6018 Validation loss: 4.2059
# Epoch: 251 Train loss: 1.3018 Validation loss: 3.7631
# Epoch: 252 Train loss: 1.286 Validation loss: 4.0925
# Epoch: 253 Train loss: 1.3088 Validation loss: 3.7076
# Epoch: 254 Train loss: 1.0629 Validation loss: 3.7405
# Epoch: 255 Train loss: 1.2067 Validation loss: 3.8673
# Epoch: 256 Train loss: 1.2163 Validation loss: 3.9564
# Epoch: 257 Train loss: 1.2065 Validation loss: 3.6963
# Epoch: 258 Train loss: 1.1469 Validation loss: 3.7779
# Epoch: 259 Train loss: 1.0704 Validation loss: 3.7169
# Epoch: 260 Train loss: 1.113 Validation loss: 4.0056
# Epoch: 261 Train loss: 1.1895 Validation loss: 4.295
# Epoch: 262 Train loss: 1.1122 Validation loss: 3.6756
# Epoch: 263 Train loss: 1.1236 Validation loss: 3.9998
# Epoch: 264 Train loss: 1.0887 Validation loss: 3.7725
# Epoch: 265 Train loss: 1.3663 Validation loss: 3.6446
# Epoch: 266 Train loss: 1.0509 Validation loss: 3.75
# Epoch: 267 Train loss: 1.1594 Validation loss: 3.8424
# Epoch: 268 Train loss: 1.1702 Validation loss: 3.6814
# Epoch: 269 Train loss: 1.3616 Validation loss: 5.0058
# Epoch: 270 Train loss: 1.1711 Validation loss: 3.6863
# Epoch: 271 Train loss: 1.1184 Validation loss: 3.7674
# Epoch: 272 Train loss: 1.1124 Validation loss: 4.0552
# Epoch: 273 Train loss: 1.1856 Validation loss: 3.6209
# Epoch: 274 Train loss: 1.0674 Validation loss: 3.6435
# Epoch: 275 Train loss: 1.0755 Validation loss: 3.6979
# Epoch: 276 Train loss: 1.0235 Validation loss: 3.8188
# Epoch: 277 Train loss: 1.17 Validation loss: 3.6821
# Epoch: 278 Train loss: 1.095 Validation loss: 3.7035
# Epoch: 279 Train loss: 1.0798 Validation loss: 4.5444
# Epoch: 280 Train loss: 1.0518 Validation loss: 3.8201
# Epoch: 281 Train loss: 1.2607 Validation loss: 4.01
# Epoch: 282 Train loss: 1.0985 Validation loss: 3.7155
# Epoch: 283 Train loss: 1.1539 Validation loss: 3.7124
# Epoch: 284 Train loss: 1.0321 Validation loss: 4.5029
# Epoch: 285 Train loss: 1.2297 Validation loss: 4.0045
# Epoch: 286 Train loss: 1.3146 Validation loss: 3.7374
# Epoch: 287 Train loss: 1.1237 Validation loss: 3.9257
# Epoch: 288 Train loss: 1.1246 Validation loss: 3.6833
# Epoch: 289 Train loss: 1.1155 Validation loss: 4.445
# Epoch: 290 Train loss: 1.1185 Validation loss: 3.8248
# Epoch: 291 Train loss: 1.2254 Validation loss: 3.6413
# Epoch: 292 Train loss: 1.0743 Validation loss: 3.6266
# Epoch: 293 Train loss: 1.1759 Validation loss: 3.7598
# Epoch: 294 Train loss: 1.1159 Validation loss: 3.967
# Epoch: 295 Train loss: 1.0665 Validation loss: 3.6956
# Epoch: 296 Train loss: 1.0823 Validation loss: 3.8085
# Epoch: 297 Train loss: 1.5395 Validation loss: 4.0805
# Epoch: 298 Train loss: 1.0676 Validation loss: 3.7515
# Epoch: 299 Train loss: 1.0684 Validation loss: 3.7169
# Epoch: 300 Train loss: 1.0521 Validation loss: 3.9033
# Epoch: 301 Train loss: 1.0923 Validation loss: 3.9897
# Epoch: 302 Train loss: 1.1695 Validation loss: 4.4627
# Epoch: 303 Train loss: 1.1821 Validation loss: 3.6987
# Epoch: 304 Train loss: 1.0552 Validation loss: 3.7171
# Epoch: 305 Train loss: 1.1039 Validation loss: 3.9866
# Epoch: 306 Train loss: 1.2178 Validation loss: 3.849
# Epoch: 307 Train loss: 1.0656 Validation loss: 3.8792
# Epoch: 308 Train loss: 1.0715 Validation loss: 4.3707
# Epoch: 309 Train loss: 1.066 Validation loss: 3.7993
# Epoch: 310 Train loss: 1.1823 Validation loss: 4.0761
# Epoch: 311 Train loss: 1.2893 Validation loss: 3.7186
# Epoch: 312 Train loss: 1.2024 Validation loss: 3.9056
# Epoch: 313 Train loss: 1.2966 Validation loss: 3.9476
# Epoch: 314 Train loss: 1.1344 Validation loss: 3.6958
# Epoch: 315 Train loss: 1.0967 Validation loss: 3.8784
# Epoch: 316 Train loss: 1.213 Validation loss: 4.9279
# Epoch: 317 Train loss: 1.9262 Validation loss: 3.6848
# Epoch: 318 Train loss: 1.12 Validation loss: 4.1917
# Epoch: 319 Train loss: 1.1881 Validation loss: 5.2318
# Epoch: 320 Train loss: 1.1807 Validation loss: 3.694
# Epoch: 321 Train loss: 1.2699 Validation loss: 3.7392
# Epoch: 322 Train loss: 1.1889 Validation loss: 3.6883
# Epoch: 323 Train loss: 1.1779 Validation loss: 4.6248
# Epoch: 324 Train loss: 1.2749 Validation loss: 3.9461
# Epoch: 325 Train loss: 1.0955 Validation loss: 3.7031
# Epoch: 326 Train loss: 1.0486 Validation loss: 3.7304
# Epoch: 327 Train loss: 1.1525 Validation loss: 4.0246
# Epoch: 328 Train loss: 1.2237 Validation loss: 3.7424
# Epoch: 329 Train loss: 1.0909 Validation loss: 3.7474
# Epoch: 330 Train loss: 1.2416 Validation loss: 5.9451
# Epoch: 331 Train loss: 1.5229 Validation loss: 3.7348
# Epoch: 332 Train loss: 1.1919 Validation loss: 4.03
# Epoch: 333 Train loss: 1.6192 Validation loss: 4.0992
# Epoch: 334 Train loss: 1.0714 Validation loss: 3.7078
# Epoch: 335 Train loss: 0.99864 Validation loss: 3.6033
# Epoch: 336 Train loss: 1.2417 Validation loss: 3.8292
# Epoch: 337 Train loss: 1.1861 Validation loss: 3.9118
# Epoch: 338 Train loss: 1.1994 Validation loss: 3.931
# Epoch: 339 Train loss: 1.1411 Validation loss: 3.6504
# Epoch: 340 Train loss: 1.0174 Validation loss: 3.9407
# Epoch: 341 Train loss: 1.0698 Validation loss: 3.6082
# Epoch: 342 Train loss: 1.1622 Validation loss: 3.5991
# Epoch: 343 Train loss: 1.0554 Validation loss: 3.819
# Epoch: 344 Train loss: 1.207 Validation loss: 6.5379
# Epoch: 345 Train loss: 1.2709 Validation loss: 3.7579
# Epoch: 346 Train loss: 1.248 Validation loss: 3.6485
# Epoch: 347 Train loss: 1.1928 Validation loss: 3.9798
# Epoch: 348 Train loss: 0.99921 Validation loss: 3.5676
# Epoch: 349 Train loss: 1.1556 Validation loss: 3.573
# Epoch: 350 Train loss: 1.0421 Validation loss: 3.6397
# Epoch: 351 Train loss: 1.1215 Validation loss: 3.6063
# Epoch: 352 Train loss: 1.1724 Validation loss: 3.5748
# Epoch: 353 Train loss: 1.1191 Validation loss: 3.6653
# Epoch: 354 Train loss: 1.237 Validation loss: 3.6737
# Epoch: 355 Train loss: 1.0582 Validation loss: 3.5602
# Epoch: 356 Train loss: 1.1871 Validation loss: 3.8766
# Epoch: 357 Train loss: 1.077 Validation loss: 4.0277
# Epoch: 358 Train loss: 1.113 Validation loss: 3.6415
# Epoch: 359 Train loss: 1.0105 Validation loss: 3.6366
# Epoch: 360 Train loss: 1.2109 Validation loss: 4.3442
# Epoch: 361 Train loss: 1.2257 Validation loss: 3.6409
# Epoch: 362 Train loss: 1.1892 Validation loss: 3.7529
# Epoch: 363 Train loss: 1.1186 Validation loss: 3.5466
# Epoch: 364 Train loss: 1.0708 Validation loss: 3.7606
# Epoch: 365 Train loss: 1.059 Validation loss: 3.8445
# Epoch: 366 Train loss: 1.1685 Validation loss: 3.611
# Epoch: 367 Train loss: 1.0683 Validation loss: 3.6733
# Epoch: 368 Train loss: 1.0568 Validation loss: 4.185
# Epoch: 369 Train loss: 1.0491 Validation loss: 3.8619
# Epoch: 370 Train loss: 1.0548 Validation loss: 4.5353
# Epoch: 371 Train loss: 1.1897 Validation loss: 3.6953
# Epoch: 372 Train loss: 1.05 Validation loss: 3.6216
# Epoch: 373 Train loss: 1.0207 Validation loss: 3.5655
# Epoch: 374 Train loss: 1.2815 Validation loss: 3.6314
# Epoch: 375 Train loss: 1.0487 Validation loss: 4.1011
# Epoch: 376 Train loss: 1.0948 Validation loss: 3.5262
# Epoch: 377 Train loss: 1.1095 Validation loss: 3.6248
# Epoch: 378 Train loss: 1.0771 Validation loss: 4.8123
# Epoch: 379 Train loss: 2.1003 Validation loss: 3.7092
# Epoch: 380 Train loss: 1.0837 Validation loss: 3.4597
# Epoch: 381 Train loss: 1.2122 Validation loss: 3.5575
# Epoch: 382 Train loss: 1.3069 Validation loss: 4.0945
# Epoch: 383 Train loss: 1.3244 Validation loss: 3.5233
# Epoch: 384 Train loss: 1.0354 Validation loss: 3.7147
# Epoch: 385 Train loss: 1.3279 Validation loss: 3.7857
# Epoch: 386 Train loss: 1.0464 Validation loss: 3.8583
# Epoch: 387 Train loss: 0.98408 Validation loss: 4.3949
# Epoch: 388 Train loss: 1.3502 Validation loss: 3.3985
# Epoch: 389 Train loss: 1.029 Validation loss: 3.5448
# Epoch: 390 Train loss: 1.1647 Validation loss: 3.5463
# Epoch: 391 Train loss: 1.0318 Validation loss: 3.9815
# Epoch: 392 Train loss: 1.0657 Validation loss: 3.4742
# Epoch: 393 Train loss: 1.0174 Validation loss: 3.8346
# Epoch: 394 Train loss: 1.7474 Validation loss: 3.7052
# Epoch: 395 Train loss: 1.1249 Validation loss: 3.4427
# Epoch: 396 Train loss: 1.1334 Validation loss: 3.5206
# Epoch: 397 Train loss: 1.104 Validation loss: 3.423
# Epoch: 398 Train loss: 1.2241 Validation loss: 3.564
# Epoch: 399 Train loss: 1.0516 Validation loss: 3.5035
# Epoch: 400 Train loss: 1.0881 Validation loss: 3.8019
# Epoch: 401 Train loss: 1.0676 Validation loss: 3.584
# Epoch: 402 Train loss: 1.0536 Validation loss: 3.4743
# Epoch: 403 Train loss: 1.1524 Validation loss: 3.3071
# Epoch: 404 Train loss: 1.0711 Validation loss: 3.9446
# Epoch: 405 Train loss: 1.2407 Validation loss: 3.3
# Epoch: 406 Train loss: 1.0118 Validation loss: 3.256
# Epoch: 407 Train loss: 1.125 Validation loss: 3.4476
# Epoch: 408 Train loss: 1.0645 Validation loss: 3.5273
# Epoch: 409 Train loss: 1.1637 Validation loss: 4.4114
# Epoch: 410 Train loss: 1.0524 Validation loss: 3.5673
# Epoch: 411 Train loss: 1.016 Validation loss: 3.3286
# Epoch: 412 Train loss: 1.0409 Validation loss: 3.3199
# Epoch: 413 Train loss: 1.0219 Validation loss: 3.536
# Epoch: 414 Train loss: 1.1181 Validation loss: 3.4479
# Epoch: 415 Train loss: 1.07 Validation loss: 3.3883
# Epoch: 416 Train loss: 1.2754 Validation loss: 3.6071
# Epoch: 417 Train loss: 1.2323 Validation loss: 3.4585
# Epoch: 418 Train loss: 1.044 Validation loss: 4.077
# Epoch: 419 Train loss: 1.092 Validation loss: 3.4233
# Epoch: 420 Train loss: 1.0954 Validation loss: 3.6255
# Epoch: 421 Train loss: 0.9883 Validation loss: 3.3032
# Epoch: 422 Train loss: 1.1667 Validation loss: 3.5335
# Epoch: 423 Train loss: 1.2217 Validation loss: 3.5632
# Epoch: 424 Train loss: 1.1801 Validation loss: 3.5203
# Epoch: 425 Train loss: 1.1794 Validation loss: 3.3182
# Epoch: 426 Train loss: 1.091 Validation loss: 3.422
# Epoch: 427 Train loss: 1.1087 Validation loss: 3.3405
# Epoch: 428 Train loss: 0.98752 Validation loss: 3.5177
# Epoch: 429 Train loss: 1.0015 Validation loss: 3.3925
# Epoch: 430 Train loss: 0.99531 Validation loss: 3.4708
# Epoch: 431 Train loss: 1.2416 Validation loss: 3.2245
# Epoch: 432 Train loss: 1.1632 Validation loss: 3.5031
# Epoch: 433 Train loss: 1.1606 Validation loss: 3.7485
# Epoch: 434 Train loss: 1.3511 Validation loss: 3.701
# Epoch: 435 Train loss: 1.1999 Validation loss: 3.4228
# Epoch: 436 Train loss: 1.1415 Validation loss: 3.3481
# Epoch: 437 Train loss: 1.0274 Validation loss: 3.5027
# Epoch: 438 Train loss: 1.2117 Validation loss: 3.4216
# Epoch: 439 Train loss: 1.1064 Validation loss: 3.5897
# Epoch: 440 Train loss: 1.0607 Validation loss: 3.3448
# Epoch: 441 Train loss: 0.98678 Validation loss: 3.3612
# Epoch: 442 Train loss: 1.0667 Validation loss: 3.8303
# Epoch: 443 Train loss: 1.0726 Validation loss: 3.2609
# Epoch: 444 Train loss: 1.0548 Validation loss: 3.3544
# Epoch: 445 Train loss: 1.1436 Validation loss: 3.4378
# Epoch: 446 Train loss: 1.359 Validation loss: 3.3521
# Epoch: 447 Train loss: 1.0181 Validation loss: 3.741
# Epoch: 448 Train loss: 1.0217 Validation loss: 3.3268
# Epoch: 449 Train loss: 1.1089 Validation loss: 3.3884
# Epoch: 450 Train loss: 1.0073 Validation loss: 3.3488
# Epoch: 451 Train loss: 1.2258 Validation loss: 3.4453
# Epoch: 452 Train loss: 1.1863 Validation loss: 4.1479
# Epoch: 453 Train loss: 1.3281 Validation loss: 3.8545
# Epoch: 454 Train loss: 1.1403 Validation loss: 3.6581
# Epoch: 455 Train loss: 1.2854 Validation loss: 4.8426
# Epoch: 456 Train loss: 1.3523 Validation loss: 3.4126
# Epoch: 457 Train loss: 1.0871 Validation loss: 3.6867
# Epoch: 458 Train loss: 1.1481 Validation loss: 3.7655
# Epoch: 459 Train loss: 1.2446 Validation loss: 3.2569
# Epoch: 460 Train loss: 0.97989 Validation loss: 4.2511
# Epoch: 461 Train loss: 1.3928 Validation loss: 3.697
# Epoch: 462 Train loss: 1.0168 Validation loss: 3.3505
# Epoch: 463 Train loss: 1.0254 Validation loss: 3.2244
# Epoch: 464 Train loss: 1.0902 Validation loss: 3.5109
# Epoch: 465 Train loss: 1.1608 Validation loss: 3.2037
# Epoch: 466 Train loss: 1.0893 Validation loss: 3.857
# Epoch: 467 Train loss: 1.2592 Validation loss: 4.8728
# Epoch: 468 Train loss: 1.1975 Validation loss: 3.7604
# Epoch: 469 Train loss: 1.1972 Validation loss: 3.2945
# Epoch: 470 Train loss: 1.119 Validation loss: 3.515
# Epoch: 471 Train loss: 1.3593 Validation loss: 4.1337
# Epoch: 472 Train loss: 1.6375 Validation loss: 3.2543
# Epoch: 473 Train loss: 0.95867 Validation loss: 3.4366
# Epoch: 474 Train loss: 1.1535 Validation loss: 3.4135
# Epoch: 475 Train loss: 1.0219 Validation loss: 3.2855
# Epoch: 476 Train loss: 1.0087 Validation loss: 3.313
# Epoch: 477 Train loss: 1.0094 Validation loss: 3.3634
# Epoch: 478 Train loss: 1.1428 Validation loss: 3.3147
# Epoch: 479 Train loss: 0.99161 Validation loss: 3.2456
# Epoch: 480 Train loss: 0.95444 Validation loss: 3.8168
# Epoch: 481 Train loss: 1.0832 Validation loss: 3.3948
# Epoch: 482 Train loss: 1.0666 Validation loss: 3.3826
# Epoch: 483 Train loss: 0.97622 Validation loss: 3.407
# Epoch: 484 Train loss: 1.164 Validation loss: 3.3313
# Epoch: 485 Train loss: 1.0907 Validation loss: 3.3727
# Epoch: 486 Train loss: 0.99558 Validation loss: 3.3761
# Epoch: 487 Train loss: 1.1074 Validation loss: 3.7848
# Epoch: 488 Train loss: 1.0488 Validation loss: 3.3373
# Epoch: 489 Train loss: 1.0478 Validation loss: 3.6161
# Epoch: 490 Train loss: 1.1168 Validation loss: 3.2709
# Epoch: 491 Train loss: 1.1737 Validation loss: 3.2075
# Epoch: 492 Train loss: 1.1017 Validation loss: 3.2591
# Epoch: 493 Train loss: 1.3373 Validation loss: 3.7613
# Epoch: 494 Train loss: 1.2255 Validation loss: 3.782
# Epoch: 495 Train loss: 1.1395 Validation loss: 3.9582
# Epoch: 496 Train loss: 1.3785 Validation loss: 3.301
# Epoch: 497 Train loss: 1.123 Validation loss: 3.8026
# Epoch: 498 Train loss: 1.2098 Validation loss: 3.8638
# Epoch: 499 Train loss: 1.1814 Validation loss: 3.6715

# %% [markdown]
# Predicting with this model shows overfitting. For recognizing overfitting a comparison of the validation and training loss is very useful. If the training loss decreases during training while the validation loss consistently increases, the model you are training is probably overfitting. Plotting the models prediction and the target also shows that there is a significant discrepancy between the target and the prediction of the model.

# %%
y_pred = tf.reshape(tf.map_fn(big_mdl, x), shape=[N_samples,])
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Target", "Prediction", "Training samples"])
plt.show()

# %% [markdown]
# In order to implement a regularization we need to modify the loss function. Since the loss function in this exercise is computed during the training step, we define a new training step with a regularization.

# %%
""" In order to avoid overfitting we implement a training step that also includes a regularization on the weights of our big model. For this we use the Frobenius/squared l2-norm of each weight matrix/vector. 
Hint: Use the tf.reduce_sum() function on a list of individual regularization terms for each matrix/vector of the network."""

def regularized_train_step(model, optimizer, x, y, lmbd):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model(x)# Compute a prediction with "model" on the input "x"
        loss_val =  tf.math.reduce_mean(tf.math.squared_difference(y_pred,y))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
        regul_val = tf.norm(model.W0,ord=1) + tf.norm(model.W1,ord=1) + tf.norm(model.W2,ord=1)# Compute the regularization based on the list "model.trainable_variables"
        total_loss = tf.reduce_mean(loss_val + lmbd * regul_val)# Add the loss with a the regularization term weighted by "lmbd"
    grads = tape.gradient(loss_val, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# We can now set the strength of the regularization and retrain the big model with a regularization. We create another instance of the big model in order to compare the big model with and without regularization.

# %%
""" Implement the training for the bigger model with the regularized_train_step function. Note: We are plotting the MSE loss without the regularization in order to compare it with the unregularized model. """

lmbd = 0.005

big_reg_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    for x_t_batch, y_t_batch in zip(x_t, y_t):
      train_loss += regularized_train_step(big_reg_mdl, big_opt, x_t_batch, y_t_batch, lmbd)# Perform a regularized training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t" with the regularization parameter being "lmbd"
    train_iters += 1
    if (batch_size * train_iters == N_train_samples_overfit):# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = big_reg_mdl(x_v)# Compute a prediction with "big_mdl" on the input "x_v"
            validation_loss = tf.reduce_mean(tf.math.squared_difference(y_pred,y_v))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        train_reg = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 38.513 Validation loss: 0.00011076
# Epoch: 1 Train loss: 31.358 Validation loss: 3.8689
# Epoch: 2 Train loss: 19.753 Validation loss: 0.024909
# Epoch: 3 Train loss: 27.022 Validation loss: 3.9647
# Epoch: 4 Train loss: 12.592 Validation loss: 9.07e-07
# Epoch: 5 Train loss: 16.132 Validation loss: 0.0082057
# Epoch: 6 Train loss: 6.2982 Validation loss: 0.0035573
# Epoch: 7 Train loss: 11.947 Validation loss: 3.163
# Epoch: 8 Train loss: 19.815 Validation loss: 0.0053449
# Epoch: 9 Train loss: 9.3728 Validation loss: 2.5134e-05
# Epoch: 10 Train loss: 4.4865 Validation loss: 0.00010468
# Epoch: 11 Train loss: 5.4187 Validation loss: 6.2141e-05
# Epoch: 12 Train loss: 4.2477 Validation loss: 5.0277e-05
# Epoch: 13 Train loss: 1.831 Validation loss: 0.00042033
# Epoch: 14 Train loss: 3.7684 Validation loss: 1.8357e-05
# Epoch: 15 Train loss: 2.1391 Validation loss: 7.1311e-05
# Epoch: 16 Train loss: 3.8295 Validation loss: 0.00038773
# Epoch: 17 Train loss: 2.1749 Validation loss: 2.7437e-07
# Epoch: 18 Train loss: 1.6664 Validation loss: 0.00063736
# Epoch: 19 Train loss: 1.6666 Validation loss: 0.00029093
# Epoch: 20 Train loss: 2.2089 Validation loss: 5.5148e-07
# Epoch: 21 Train loss: 2.5511 Validation loss: 1.2349e-05
# Epoch: 22 Train loss: 1.8656 Validation loss: 3.8572e-08
# Epoch: 23 Train loss: 2.7527 Validation loss: 0.0003527
# Epoch: 24 Train loss: 2.1466 Validation loss: 0.00044466
# Epoch: 25 Train loss: 2.0231 Validation loss: 0.00024144
# Epoch: 26 Train loss: 1.9554 Validation loss: 3.3125e-07
# Epoch: 27 Train loss: 3.1514 Validation loss: 8.7062e-05
# Epoch: 28 Train loss: 5.7757 Validation loss: 0.041523
# Epoch: 29 Train loss: 5.918 Validation loss: 3.9513e-05
# Epoch: 30 Train loss: 2.7976 Validation loss: 7.1365e-05
# Epoch: 31 Train loss: 1.8005 Validation loss: 1.432e-06
# Epoch: 32 Train loss: 2.4705 Validation loss: 6.4422e-07
# Epoch: 33 Train loss: 1.8634 Validation loss: 6.641e-06
# Epoch: 34 Train loss: 2.6517 Validation loss: 9.5218e-05
# Epoch: 35 Train loss: 2.313 Validation loss: 0.00044437
# Epoch: 36 Train loss: 1.2683 Validation loss: 9.7531e-05
# Epoch: 37 Train loss: 1.4493 Validation loss: 3.983e-05
# Epoch: 38 Train loss: 2.0835 Validation loss: 4.6646e-06
# Epoch: 39 Train loss: 2.3806 Validation loss: 6.2277e-06
# Epoch: 40 Train loss: 4.3529 Validation loss: 3.5149e-06
# Epoch: 41 Train loss: 1.5223 Validation loss: 3.4818e-05
# Epoch: 42 Train loss: 1.3866 Validation loss: 4.6268e-07
# Epoch: 43 Train loss: 1.6743 Validation loss: 3.1198e-07
# Epoch: 44 Train loss: 1.6976 Validation loss: 1.3547e-06
# Epoch: 45 Train loss: 1.0905 Validation loss: 0.00016467
# Epoch: 46 Train loss: 1.7502 Validation loss: 6.3258e-05
# Epoch: 47 Train loss: 1.0712 Validation loss: 1.4285e-05
# Epoch: 48 Train loss: 1.4713 Validation loss: 1.6954e-05
# Epoch: 49 Train loss: 1.4609 Validation loss: 5.5469e-05
# Epoch: 50 Train loss: 1.8894 Validation loss: 1.1149e-07
# Epoch: 51 Train loss: 1.3266 Validation loss: 1.2647e-05
# Epoch: 52 Train loss: 1.3141 Validation loss: 9.6984e-06
# Epoch: 53 Train loss: 1.8842 Validation loss: 1.5359e-07
# Epoch: 54 Train loss: 1.2772 Validation loss: 4.3726e-05
# Epoch: 55 Train loss: 1.7999 Validation loss: 4.6502e-06
# Epoch: 56 Train loss: 1.4882 Validation loss: 3.5367e-05
# Epoch: 57 Train loss: 1.1046 Validation loss: 1.5177e-07
# Epoch: 58 Train loss: 1.2262 Validation loss: 2.9192e-06
# Epoch: 59 Train loss: 1.5207 Validation loss: 6.5248e-07
# Epoch: 60 Train loss: 0.98699 Validation loss: 6.994e-05
# Epoch: 61 Train loss: 1.2374 Validation loss: 0.00042578
# Epoch: 62 Train loss: 1.0719 Validation loss: 0.00011562
# Epoch: 63 Train loss: 1.3978 Validation loss: 0.0002373
# Epoch: 64 Train loss: 1.5536 Validation loss: 6.9373e-05
# Epoch: 65 Train loss: 1.3059 Validation loss: 6.2283e-06
# Epoch: 66 Train loss: 1.1513 Validation loss: 3.691e-05
# Epoch: 67 Train loss: 1.3353 Validation loss: 1.055e-05
# Epoch: 68 Train loss: 1.0999 Validation loss: 1.0454e-05
# Epoch: 69 Train loss: 1.2931 Validation loss: 5.0575e-05
# Epoch: 70 Train loss: 0.95213 Validation loss: 1.3591e-05
# Epoch: 71 Train loss: 1.3473 Validation loss: 4.3823e-05
# Epoch: 72 Train loss: 1.0115 Validation loss: 6.8664e-05
# Epoch: 73 Train loss: 1.1961 Validation loss: 2.2811e-05
# Epoch: 74 Train loss: 1.8137 Validation loss: 4.7998e-05
# Epoch: 75 Train loss: 1.0046 Validation loss: 1.2487e-05
# Epoch: 76 Train loss: 1.2126 Validation loss: 1.0399e-06
# Epoch: 77 Train loss: 1.3392 Validation loss: 0.00024159
# Epoch: 78 Train loss: 1.3064 Validation loss: 0.0007258
# Epoch: 79 Train loss: 1.3955 Validation loss: 0.00010456
# Epoch: 80 Train loss: 1.0296 Validation loss: 0.00076875
# Epoch: 81 Train loss: 0.91829 Validation loss: 0.00017522
# Epoch: 82 Train loss: 1.1512 Validation loss: 0.00092019
# Epoch: 83 Train loss: 1.5006 Validation loss: 0.0022266
# Epoch: 84 Train loss: 1.1182 Validation loss: 0.00020155
# Epoch: 85 Train loss: 1.6884 Validation loss: 0.00099827
# Epoch: 86 Train loss: 1.1659 Validation loss: 0.0012176
# Epoch: 87 Train loss: 1.1486 Validation loss: 0.00021723
# Epoch: 88 Train loss: 1.7156 Validation loss: 0.0012656
# Epoch: 89 Train loss: 0.90716 Validation loss: 0.0016549
# Epoch: 90 Train loss: 1.1586 Validation loss: 0.0016854
# Epoch: 91 Train loss: 0.97295 Validation loss: 0.0011322
# Epoch: 92 Train loss: 0.8992 Validation loss: 0.00072347
# Epoch: 93 Train loss: 1.0596 Validation loss: 0.00057987
# Epoch: 94 Train loss: 1.2623 Validation loss: 0.00077591
# Epoch: 95 Train loss: 1.0716 Validation loss: 0.0055882
# Epoch: 96 Train loss: 1.1228 Validation loss: 0.0014749
# Epoch: 97 Train loss: 1.1809 Validation loss: 0.00062806
# Epoch: 98 Train loss: 1.1225 Validation loss: 0.0039596
# Epoch: 99 Train loss: 1.1109 Validation loss: 0.0023498
# Epoch: 100 Train loss: 0.96553 Validation loss: 0.00097657
# Epoch: 101 Train loss: 1.583 Validation loss: 0.0069997
# Epoch: 102 Train loss: 1.1955 Validation loss: 5.7445e-05
# Epoch: 103 Train loss: 1.4771 Validation loss: 0.00013414
# Epoch: 104 Train loss: 1.1265 Validation loss: 0.00028777
# Epoch: 105 Train loss: 1.3132 Validation loss: 0.00051604
# Epoch: 106 Train loss: 1.2651 Validation loss: 0.0001757
# Epoch: 107 Train loss: 1.2052 Validation loss: 6.0742e-05
# Epoch: 108 Train loss: 1.6548 Validation loss: 0.00032912
# Epoch: 109 Train loss: 1.1073 Validation loss: 0.0019559
# Epoch: 110 Train loss: 1.1863 Validation loss: 0.0013806
# Epoch: 111 Train loss: 1.4823 Validation loss: 0.00095439
# Epoch: 112 Train loss: 1.0817 Validation loss: 0.0053321
# Epoch: 113 Train loss: 1.0045 Validation loss: 9.9657e-05
# Epoch: 114 Train loss: 1.04 Validation loss: 0.0031293
# Epoch: 115 Train loss: 1.0376 Validation loss: 0.00082671
# Epoch: 116 Train loss: 1.127 Validation loss: 0.0011236
# Epoch: 117 Train loss: 0.98208 Validation loss: 0.0023807
# Epoch: 118 Train loss: 0.82651 Validation loss: 0.00011973
# Epoch: 119 Train loss: 1.1215 Validation loss: 0.00062453
# Epoch: 120 Train loss: 1.8001 Validation loss: 0.0015225
# Epoch: 121 Train loss: 1.1551 Validation loss: 0.00024681
# Epoch: 122 Train loss: 1.2259 Validation loss: 0.00061055
# Epoch: 123 Train loss: 0.8398 Validation loss: 0.0030226
# Epoch: 124 Train loss: 1.3081 Validation loss: 0.00060967
# Epoch: 125 Train loss: 0.94631 Validation loss: 0.0018958
# Epoch: 126 Train loss: 0.80672 Validation loss: 0.00063606
# Epoch: 127 Train loss: 1.204 Validation loss: 0.00063741
# Epoch: 128 Train loss: 0.99195 Validation loss: 0.0015922
# Epoch: 129 Train loss: 1.2806 Validation loss: 0.0027613
# Epoch: 130 Train loss: 1.0478 Validation loss: 0.002263
# Epoch: 131 Train loss: 1.1407 Validation loss: 0.0023914
# Epoch: 132 Train loss: 0.90444 Validation loss: 0.00056725
# Epoch: 133 Train loss: 1.0109 Validation loss: 0.0012162
# Epoch: 134 Train loss: 0.86173 Validation loss: 0.001318
# Epoch: 135 Train loss: 0.95584 Validation loss: 0.0028682
# Epoch: 136 Train loss: 1.0611 Validation loss: 0.00046994
# Epoch: 137 Train loss: 0.90099 Validation loss: 0.002308
# Epoch: 138 Train loss: 0.83278 Validation loss: 4.4629e-05
# Epoch: 139 Train loss: 1.0487 Validation loss: 0.00036633
# Epoch: 140 Train loss: 1.1843 Validation loss: 0.0014542
# Epoch: 141 Train loss: 1.0086 Validation loss: 0.0023584
# Epoch: 142 Train loss: 1.0399 Validation loss: 0.0023959
# Epoch: 143 Train loss: 1.5981 Validation loss: 0.0009974
# Epoch: 144 Train loss: 0.81351 Validation loss: 0.0009756
# Epoch: 145 Train loss: 0.91505 Validation loss: 0.00039619
# Epoch: 146 Train loss: 0.84807 Validation loss: 0.0012415
# Epoch: 147 Train loss: 0.95387 Validation loss: 0.00058266
# Epoch: 148 Train loss: 0.96184 Validation loss: 0.00065193
# Epoch: 149 Train loss: 0.91145 Validation loss: 0.0010856
# Epoch: 150 Train loss: 0.98355 Validation loss: 0.0050019
# Epoch: 151 Train loss: 1.244 Validation loss: 0.0022414
# Epoch: 152 Train loss: 1.2812 Validation loss: 0.0039495
# Epoch: 153 Train loss: 0.98793 Validation loss: 0.00043139
# Epoch: 154 Train loss: 0.95134 Validation loss: 0.0035711
# Epoch: 155 Train loss: 0.92791 Validation loss: 0.0010737
# Epoch: 156 Train loss: 0.99495 Validation loss: 0.00073783
# Epoch: 157 Train loss: 1.2214 Validation loss: 0.0015765
# Epoch: 158 Train loss: 0.98817 Validation loss: 0.00398
# Epoch: 159 Train loss: 0.8091 Validation loss: 0.0022502
# Epoch: 160 Train loss: 0.83288 Validation loss: 0.0010875
# Epoch: 161 Train loss: 1.1403 Validation loss: 0.0011169
# Epoch: 162 Train loss: 1.276 Validation loss: 0.00061573
# Epoch: 163 Train loss: 1.1338 Validation loss: 0.002294
# Epoch: 164 Train loss: 1.0467 Validation loss: 0.0005954
# Epoch: 165 Train loss: 1.4389 Validation loss: 0.0015153
# Epoch: 166 Train loss: 0.93815 Validation loss: 0.00058074
# Epoch: 167 Train loss: 1.0616 Validation loss: 0.002137
# Epoch: 168 Train loss: 1.0844 Validation loss: 0.0025861
# Epoch: 169 Train loss: 0.96175 Validation loss: 0.0015559
# Epoch: 170 Train loss: 0.97631 Validation loss: 0.00059255
# Epoch: 171 Train loss: 0.94558 Validation loss: 0.0017439
# Epoch: 172 Train loss: 0.97191 Validation loss: 0.0047431
# Epoch: 173 Train loss: 1.1344 Validation loss: 0.00056887
# Epoch: 174 Train loss: 0.91263 Validation loss: 0.00035449
# Epoch: 175 Train loss: 0.7699 Validation loss: 0.0012292
# Epoch: 176 Train loss: 0.96649 Validation loss: 0.0050063
# Epoch: 177 Train loss: 0.84427 Validation loss: 0.0011822
# Epoch: 178 Train loss: 0.83798 Validation loss: 0.00068346
# Epoch: 179 Train loss: 0.80155 Validation loss: 0.0054552
# Epoch: 180 Train loss: 1.0352 Validation loss: 0.00091397
# Epoch: 181 Train loss: 1.0325 Validation loss: 0.0004011
# Epoch: 182 Train loss: 0.99525 Validation loss: 0.0020368
# Epoch: 183 Train loss: 0.89108 Validation loss: 0.001244
# Epoch: 184 Train loss: 0.96463 Validation loss: 0.00077639
# Epoch: 185 Train loss: 0.89878 Validation loss: 0.0031864
# Epoch: 186 Train loss: 0.81469 Validation loss: 0.00024949
# Epoch: 187 Train loss: 0.85943 Validation loss: 0.00074812
# Epoch: 188 Train loss: 0.95544 Validation loss: 0.0025459
# Epoch: 189 Train loss: 1.1918 Validation loss: 0.0016421
# Epoch: 190 Train loss: 0.98021 Validation loss: 0.00091674
# Epoch: 191 Train loss: 1.0987 Validation loss: 0.00049243
# Epoch: 192 Train loss: 0.92848 Validation loss: 0.00041025
# Epoch: 193 Train loss: 0.79108 Validation loss: 0.00051339
# Epoch: 194 Train loss: 1.2115 Validation loss: 0.0012149
# Epoch: 195 Train loss: 0.7166 Validation loss: 0.0034984
# Epoch: 196 Train loss: 0.97612 Validation loss: 0.0028308
# Epoch: 197 Train loss: 0.81746 Validation loss: 0.0013648
# Epoch: 198 Train loss: 0.81718 Validation loss: 0.00044626
# Epoch: 199 Train loss: 0.94185 Validation loss: 0.00095266
# Epoch: 200 Train loss: 1.0764 Validation loss: 0.00066485
# Epoch: 201 Train loss: 0.76601 Validation loss: 0.0013201
# Epoch: 202 Train loss: 1.0304 Validation loss: 0.0012554
# Epoch: 203 Train loss: 0.85604 Validation loss: 0.0014066
# Epoch: 204 Train loss: 0.85564 Validation loss: 0.0022721
# Epoch: 205 Train loss: 0.97498 Validation loss: 0.003945
# Epoch: 206 Train loss: 1.3283 Validation loss: 0.0015377
# Epoch: 207 Train loss: 1.0231 Validation loss: 0.003568
# Epoch: 208 Train loss: 1.2077 Validation loss: 0.00057849
# Epoch: 209 Train loss: 1.2866 Validation loss: 0.001746
# Epoch: 210 Train loss: 0.99505 Validation loss: 0.0023264
# Epoch: 211 Train loss: 0.69029 Validation loss: 0.0063176
# Epoch: 212 Train loss: 0.86418 Validation loss: 0.0072867
# Epoch: 213 Train loss: 0.94077 Validation loss: 0.0022625
# Epoch: 214 Train loss: 1.2503 Validation loss: 0.0003811
# Epoch: 215 Train loss: 1.0426 Validation loss: 0.0015036
# Epoch: 216 Train loss: 1.0409 Validation loss: 0.0021619
# Epoch: 217 Train loss: 0.9825 Validation loss: 0.00032909
# Epoch: 218 Train loss: 0.77317 Validation loss: 0.0011789
# Epoch: 219 Train loss: 0.888 Validation loss: 0.0018243
# Epoch: 220 Train loss: 0.76335 Validation loss: 0.0040122
# Epoch: 221 Train loss: 0.80787 Validation loss: 0.0033635
# Epoch: 222 Train loss: 0.82352 Validation loss: 0.00078379
# Epoch: 223 Train loss: 0.83948 Validation loss: 0.000521
# Epoch: 224 Train loss: 0.90746 Validation loss: 0.0033506
# Epoch: 225 Train loss: 1.143 Validation loss: 0.00066722
# Epoch: 226 Train loss: 1.0829 Validation loss: 0.00026979
# Epoch: 227 Train loss: 0.76838 Validation loss: 0.00050003
# Epoch: 228 Train loss: 0.75667 Validation loss: 0.00096302
# Epoch: 229 Train loss: 0.777 Validation loss: 0.001587
# Epoch: 230 Train loss: 0.81473 Validation loss: 0.0004229
# Epoch: 231 Train loss: 0.95995 Validation loss: 0.00057646
# Epoch: 232 Train loss: 0.92703 Validation loss: 0.00072125
# Epoch: 233 Train loss: 0.81191 Validation loss: 0.0072354
# Epoch: 234 Train loss: 0.89573 Validation loss: 0.0017718
# Epoch: 235 Train loss: 0.96812 Validation loss: 0.0010666
# Epoch: 236 Train loss: 0.60757 Validation loss: 0.00021812
# Epoch: 237 Train loss: 1.1726 Validation loss: 0.0024455
# Epoch: 238 Train loss: 0.93766 Validation loss: 0.0016943
# Epoch: 239 Train loss: 0.66228 Validation loss: 0.00014147
# Epoch: 240 Train loss: 1.0507 Validation loss: 0.0070451
# Epoch: 241 Train loss: 0.72582 Validation loss: 0.00066401
# Epoch: 242 Train loss: 1.0029 Validation loss: 0.00029843
# Epoch: 243 Train loss: 0.87749 Validation loss: 0.0014154
# Epoch: 244 Train loss: 0.78666 Validation loss: 0.00027746
# Epoch: 245 Train loss: 0.79722 Validation loss: 0.00073205
# Epoch: 246 Train loss: 0.72757 Validation loss: 0.0014672
# Epoch: 247 Train loss: 0.69073 Validation loss: 0.00625
# Epoch: 248 Train loss: 0.8885 Validation loss: 0.0054112
# Epoch: 249 Train loss: 0.76169 Validation loss: 0.0029519
# Epoch: 250 Train loss: 1.187 Validation loss: 0.00070401
# Epoch: 251 Train loss: 0.72083 Validation loss: 0.0031751
# Epoch: 252 Train loss: 0.90142 Validation loss: 0.00077532
# Epoch: 253 Train loss: 0.82705 Validation loss: 0.0019359
# Epoch: 254 Train loss: 0.68821 Validation loss: 0.0047335
# Epoch: 255 Train loss: 0.69558 Validation loss: 0.0016333
# Epoch: 256 Train loss: 0.69117 Validation loss: 0.0013137
# Epoch: 257 Train loss: 0.94125 Validation loss: 0.0014241
# Epoch: 258 Train loss: 0.71549 Validation loss: 0.0022745
# Epoch: 259 Train loss: 1.3188 Validation loss: 0.00033232
# Epoch: 260 Train loss: 0.89059 Validation loss: 0.0011637
# Epoch: 261 Train loss: 0.93333 Validation loss: 0.00076766
# Epoch: 262 Train loss: 0.53972 Validation loss: 0.0024185
# Epoch: 263 Train loss: 0.89815 Validation loss: 0.0024998
# Epoch: 264 Train loss: 0.60591 Validation loss: 0.0017703
# Epoch: 265 Train loss: 0.81262 Validation loss: 0.00010261
# Epoch: 266 Train loss: 0.58897 Validation loss: 3.2248e-05
# Epoch: 267 Train loss: 1.1162 Validation loss: 0.00010022
# Epoch: 268 Train loss: 0.77483 Validation loss: 0.00097645
# Epoch: 269 Train loss: 0.67745 Validation loss: 0.0024309
# Epoch: 270 Train loss: 0.7281 Validation loss: 0.00021352
# Epoch: 271 Train loss: 0.42817 Validation loss: 0.0029782
# Epoch: 272 Train loss: 0.76042 Validation loss: 0.0018394
# Epoch: 273 Train loss: 0.86375 Validation loss: 7.0797e-05
# Epoch: 274 Train loss: 0.7533 Validation loss: 0.0015716
# Epoch: 275 Train loss: 0.68124 Validation loss: 0.00096834
# Epoch: 276 Train loss: 0.62175 Validation loss: 0.00028143
# Epoch: 277 Train loss: 0.69964 Validation loss: 0.0011426
# Epoch: 278 Train loss: 0.79443 Validation loss: 0.0019534
# Epoch: 279 Train loss: 0.90348 Validation loss: 0.0018491
# Epoch: 280 Train loss: 0.80528 Validation loss: 0.00034901
# Epoch: 281 Train loss: 0.90641 Validation loss: 0.00016126
# Epoch: 282 Train loss: 0.77428 Validation loss: 0.0013743
# Epoch: 283 Train loss: 0.85961 Validation loss: 0.00016962
# Epoch: 284 Train loss: 0.73941 Validation loss: 0.00031898
# Epoch: 285 Train loss: 0.5765 Validation loss: 0.00082086
# Epoch: 286 Train loss: 0.81148 Validation loss: 0.0027425
# Epoch: 287 Train loss: 0.94216 Validation loss: 0.0016175
# Epoch: 288 Train loss: 0.66638 Validation loss: 0.00096809
# Epoch: 289 Train loss: 0.73801 Validation loss: 0.0019623
# Epoch: 290 Train loss: 0.82701 Validation loss: 0.00089905
# Epoch: 291 Train loss: 0.8181 Validation loss: 0.0011108
# Epoch: 292 Train loss: 0.90248 Validation loss: 0.0018799
# Epoch: 293 Train loss: 0.87263 Validation loss: 0.0001919
# Epoch: 294 Train loss: 0.93282 Validation loss: 0.00018227
# Epoch: 295 Train loss: 0.70885 Validation loss: 0.00062541
# Epoch: 296 Train loss: 0.66917 Validation loss: 0.00090711
# Epoch: 297 Train loss: 0.75465 Validation loss: 0.0014732
# Epoch: 298 Train loss: 0.78551 Validation loss: 0.00068843
# Epoch: 299 Train loss: 0.71181 Validation loss: 0.00073217
# Epoch: 300 Train loss: 0.87317 Validation loss: 0.00040207
# Epoch: 301 Train loss: 0.8719 Validation loss: 0.0014965
# Epoch: 302 Train loss: 0.78461 Validation loss: 0.0019888
# Epoch: 303 Train loss: 0.68477 Validation loss: 0.0031562
# Epoch: 304 Train loss: 0.70843 Validation loss: 0.0012535
# Epoch: 305 Train loss: 0.68319 Validation loss: 0.0012975
# Epoch: 306 Train loss: 0.59231 Validation loss: 0.0010405
# Epoch: 307 Train loss: 0.84346 Validation loss: 0.0047247
# Epoch: 308 Train loss: 0.81516 Validation loss: 0.0034154
# Epoch: 309 Train loss: 0.75775 Validation loss: 0.0049306
# Epoch: 310 Train loss: 0.58851 Validation loss: 0.0016389
# Epoch: 311 Train loss: 0.67219 Validation loss: 0.0012323
# Epoch: 312 Train loss: 0.63476 Validation loss: 0.00049893
# Epoch: 313 Train loss: 1.0191 Validation loss: 0.0013492
# Epoch: 314 Train loss: 0.65888 Validation loss: 0.0031062
# Epoch: 315 Train loss: 0.81497 Validation loss: 0.0024899
# Epoch: 316 Train loss: 0.672 Validation loss: 0.0017463
# Epoch: 317 Train loss: 0.87373 Validation loss: 0.0036535
# Epoch: 318 Train loss: 0.8424 Validation loss: 0.0031788
# Epoch: 319 Train loss: 0.75949 Validation loss: 0.00091588
# Epoch: 320 Train loss: 0.48146 Validation loss: 0.0010538
# Epoch: 321 Train loss: 0.59813 Validation loss: 0.00040594
# Epoch: 322 Train loss: 0.67931 Validation loss: 0.0012036
# Epoch: 323 Train loss: 0.69418 Validation loss: 0.0020702
# Epoch: 324 Train loss: 0.5753 Validation loss: 0.002013
# Epoch: 325 Train loss: 1.0461 Validation loss: 0.0079686
# Epoch: 326 Train loss: 0.61849 Validation loss: 0.00080155
# Epoch: 327 Train loss: 0.88062 Validation loss: 0.0016492
# Epoch: 328 Train loss: 0.59949 Validation loss: 0.001095
# Epoch: 329 Train loss: 0.81166 Validation loss: 0.001762
# Epoch: 330 Train loss: 0.66001 Validation loss: 0.0013485
# Epoch: 331 Train loss: 0.57009 Validation loss: 0.0034801
# Epoch: 332 Train loss: 0.85175 Validation loss: 0.0034248
# Epoch: 333 Train loss: 0.81348 Validation loss: 0.0054684
# Epoch: 334 Train loss: 0.78392 Validation loss: 0.0032889
# Epoch: 335 Train loss: 0.89465 Validation loss: 0.0023554
# Epoch: 336 Train loss: 0.59963 Validation loss: 0.0044324
# Epoch: 337 Train loss: 0.60626 Validation loss: 0.0044677
# Epoch: 338 Train loss: 0.63435 Validation loss: 0.0027482
# Epoch: 339 Train loss: 0.58112 Validation loss: 0.0001512
# Epoch: 340 Train loss: 0.74879 Validation loss: 0.0004305
# Epoch: 341 Train loss: 0.90677 Validation loss: 0.0014741
# Epoch: 342 Train loss: 0.72085 Validation loss: 0.0012911
# Epoch: 343 Train loss: 0.67429 Validation loss: 0.0038329
# Epoch: 344 Train loss: 0.8414 Validation loss: 0.0049268
# Epoch: 345 Train loss: 0.71175 Validation loss: 0.0016722
# Epoch: 346 Train loss: 0.64563 Validation loss: 0.001295
# Epoch: 347 Train loss: 0.40509 Validation loss: 0.0017083
# Epoch: 348 Train loss: 0.53469 Validation loss: 0.00092797
# Epoch: 349 Train loss: 0.81222 Validation loss: 0.0013949
# Epoch: 350 Train loss: 0.54878 Validation loss: 0.00084261
# Epoch: 351 Train loss: 0.62618 Validation loss: 0.0012917
# Epoch: 352 Train loss: 0.77417 Validation loss: 0.0020375
# Epoch: 353 Train loss: 0.90477 Validation loss: 0.0021668
# Epoch: 354 Train loss: 0.70438 Validation loss: 0.0020218
# Epoch: 355 Train loss: 0.74228 Validation loss: 0.002774
# Epoch: 356 Train loss: 0.7206 Validation loss: 0.0030884
# Epoch: 357 Train loss: 0.59775 Validation loss: 0.0058915
# Epoch: 358 Train loss: 0.59511 Validation loss: 0.0025358
# Epoch: 359 Train loss: 0.51263 Validation loss: 0.00042647
# Epoch: 360 Train loss: 0.63649 Validation loss: 0.0036165
# Epoch: 361 Train loss: 0.50186 Validation loss: 0.00057732
# Epoch: 362 Train loss: 0.91859 Validation loss: 0.0004778
# Epoch: 363 Train loss: 0.7227 Validation loss: 0.0007712
# Epoch: 364 Train loss: 0.50081 Validation loss: 0.0027056
# Epoch: 365 Train loss: 0.55496 Validation loss: 0.0019517
# Epoch: 366 Train loss: 0.49849 Validation loss: 0.0011387
# Epoch: 367 Train loss: 0.48856 Validation loss: 0.00098513
# Epoch: 368 Train loss: 0.45855 Validation loss: 0.0013472
# Epoch: 369 Train loss: 0.70817 Validation loss: 0.0020043
# Epoch: 370 Train loss: 0.70775 Validation loss: 0.0019966
# Epoch: 371 Train loss: 0.56588 Validation loss: 0.0060776
# Epoch: 372 Train loss: 0.71624 Validation loss: 0.00043378
# Epoch: 373 Train loss: 0.84624 Validation loss: 0.00060363
# Epoch: 374 Train loss: 0.93681 Validation loss: 0.0020796
# Epoch: 375 Train loss: 0.91005 Validation loss: 0.0015013
# Epoch: 376 Train loss: 0.56691 Validation loss: 0.0022095
# Epoch: 377 Train loss: 0.64745 Validation loss: 0.00077179
# Epoch: 378 Train loss: 0.61391 Validation loss: 0.001497
# Epoch: 379 Train loss: 0.42511 Validation loss: 0.00078426
# Epoch: 380 Train loss: 0.42703 Validation loss: 0.0014055
# Epoch: 381 Train loss: 0.4709 Validation loss: 0.00073568
# Epoch: 382 Train loss: 0.52528 Validation loss: 0.0026966
# Epoch: 383 Train loss: 0.67347 Validation loss: 0.0028869
# Epoch: 384 Train loss: 0.44625 Validation loss: 0.0031352
# Epoch: 385 Train loss: 0.48767 Validation loss: 0.00029355
# Epoch: 386 Train loss: 0.52616 Validation loss: 0.00049223
# Epoch: 387 Train loss: 0.57145 Validation loss: 0.00058854
# Epoch: 388 Train loss: 0.52888 Validation loss: 0.00037856
# Epoch: 389 Train loss: 0.84446 Validation loss: 0.0011667
# Epoch: 390 Train loss: 0.77801 Validation loss: 0.0013733
# Epoch: 391 Train loss: 0.77911 Validation loss: 0.0022837
# Epoch: 392 Train loss: 0.49232 Validation loss: 0.00084571
# Epoch: 393 Train loss: 0.5365 Validation loss: 0.00078989
# Epoch: 394 Train loss: 0.41608 Validation loss: 0.00059127
# Epoch: 395 Train loss: 0.41553 Validation loss: 0.0011958
# Epoch: 396 Train loss: 0.64123 Validation loss: 0.0014209
# Epoch: 397 Train loss: 0.59246 Validation loss: 0.00046204
# Epoch: 398 Train loss: 0.579 Validation loss: 0.0012113
# Epoch: 399 Train loss: 0.6838 Validation loss: 0.0015606
# Epoch: 400 Train loss: 0.4447 Validation loss: 0.0054239
# Epoch: 401 Train loss: 0.42182 Validation loss: 0.0027233
# Epoch: 402 Train loss: 0.60454 Validation loss: 0.0021547
# Epoch: 403 Train loss: 0.56014 Validation loss: 0.0015688
# Epoch: 404 Train loss: 0.62173 Validation loss: 0.00023681
# Epoch: 405 Train loss: 0.46733 Validation loss: 0.00068754
# Epoch: 406 Train loss: 0.52998 Validation loss: 0.0029568
# Epoch: 407 Train loss: 0.36723 Validation loss: 0.0023577
# Epoch: 408 Train loss: 0.58293 Validation loss: 0.00087912
# Epoch: 409 Train loss: 0.58477 Validation loss: 0.00066853
# Epoch: 410 Train loss: 0.72101 Validation loss: 0.0011488
# Epoch: 411 Train loss: 0.37124 Validation loss: 0.0019382
# Epoch: 412 Train loss: 0.37667 Validation loss: 0.00080799
# Epoch: 413 Train loss: 0.55277 Validation loss: 0.0032458
# Epoch: 414 Train loss: 0.77201 Validation loss: 0.0023234
# Epoch: 415 Train loss: 0.46302 Validation loss: 0.00056938
# Epoch: 416 Train loss: 0.38275 Validation loss: 0.0041663
# Epoch: 417 Train loss: 0.48294 Validation loss: 0.001562
# Epoch: 418 Train loss: 0.33099 Validation loss: 0.006435
# Epoch: 419 Train loss: 0.53307 Validation loss: 0.00067889
# Epoch: 420 Train loss: 0.64613 Validation loss: 0.0013513
# Epoch: 421 Train loss: 0.86633 Validation loss: 0.00057398
# Epoch: 422 Train loss: 0.45827 Validation loss: 0.00017476
# Epoch: 423 Train loss: 0.39317 Validation loss: 0.0011956
# Epoch: 424 Train loss: 0.47435 Validation loss: 0.0010551
# Epoch: 425 Train loss: 0.50987 Validation loss: 0.0035391
# Epoch: 426 Train loss: 0.4702 Validation loss: 0.0013759
# Epoch: 427 Train loss: 0.57385 Validation loss: 0.0010051
# Epoch: 428 Train loss: 0.40792 Validation loss: 0.0025155
# Epoch: 429 Train loss: 0.4761 Validation loss: 0.00039656
# Epoch: 430 Train loss: 0.45958 Validation loss: 0.0013467
# Epoch: 431 Train loss: 0.32963 Validation loss: 0.0006394
# Epoch: 432 Train loss: 0.54583 Validation loss: 0.0016849
# Epoch: 433 Train loss: 0.40245 Validation loss: 0.00087026
# Epoch: 434 Train loss: 0.39367 Validation loss: 0.00094379
# Epoch: 435 Train loss: 0.46418 Validation loss: 0.0011956
# Epoch: 436 Train loss: 0.51084 Validation loss: 0.00091717
# Epoch: 437 Train loss: 0.66968 Validation loss: 0.0016436
# Epoch: 438 Train loss: 0.456 Validation loss: 0.0005931
# Epoch: 439 Train loss: 1.2073 Validation loss: 0.0015788
# Epoch: 440 Train loss: 0.78188 Validation loss: 0.000889
# Epoch: 441 Train loss: 0.30304 Validation loss: 0.00033499
# Epoch: 442 Train loss: 0.35704 Validation loss: 0.00024855
# Epoch: 443 Train loss: 0.49759 Validation loss: 0.0024249
# Epoch: 444 Train loss: 0.38685 Validation loss: 0.0013582
# Epoch: 445 Train loss: 0.61831 Validation loss: 0.0010684
# Epoch: 446 Train loss: 0.46815 Validation loss: 0.0014745
# Epoch: 447 Train loss: 0.41744 Validation loss: 0.0031837
# Epoch: 448 Train loss: 0.5948 Validation loss: 0.002816
# Epoch: 449 Train loss: 0.39266 Validation loss: 0.0024789
# Epoch: 450 Train loss: 0.99854 Validation loss: 0.0029113
# Epoch: 451 Train loss: 0.37512 Validation loss: 0.0023204
# Epoch: 452 Train loss: 0.38664 Validation loss: 0.00089621
# Epoch: 453 Train loss: 0.42189 Validation loss: 0.0029193
# Epoch: 454 Train loss: 0.47592 Validation loss: 0.00080073
# Epoch: 455 Train loss: 0.29279 Validation loss: 0.0035335
# Epoch: 456 Train loss: 0.70614 Validation loss: 0.001686
# Epoch: 457 Train loss: 0.54604 Validation loss: 0.0023426
# Epoch: 458 Train loss: 0.50823 Validation loss: 0.00084589
# Epoch: 459 Train loss: 0.98549 Validation loss: 0.0089394
# Epoch: 460 Train loss: 0.7641 Validation loss: 0.00065128
# Epoch: 461 Train loss: 0.38824 Validation loss: 0.0014299
# Epoch: 462 Train loss: 0.42077 Validation loss: 0.0038487
# Epoch: 463 Train loss: 0.42137 Validation loss: 0.0012854
# Epoch: 464 Train loss: 0.37526 Validation loss: 0.0042653
# Epoch: 465 Train loss: 0.44037 Validation loss: 0.0025085
# Epoch: 466 Train loss: 0.80588 Validation loss: 0.0035163
# Epoch: 467 Train loss: 0.83368 Validation loss: 0.0005618
# Epoch: 468 Train loss: 0.8022 Validation loss: 0.0034378
# Epoch: 469 Train loss: 0.42737 Validation loss: 0.0013539
# Epoch: 470 Train loss: 0.37306 Validation loss: 0.00042198
# Epoch: 471 Train loss: 0.28817 Validation loss: 0.0065728
# Epoch: 472 Train loss: 0.27857 Validation loss: 0.00028693
# Epoch: 473 Train loss: 0.56181 Validation loss: 0.0010259
# Epoch: 474 Train loss: 0.34499 Validation loss: 0.001318
# Epoch: 475 Train loss: 0.33709 Validation loss: 0.002029
# Epoch: 476 Train loss: 0.34573 Validation loss: 0.00232
# Epoch: 477 Train loss: 0.33892 Validation loss: 0.002023
# Epoch: 478 Train loss: 0.53646 Validation loss: 0.0046533
# Epoch: 479 Train loss: 0.6985 Validation loss: 0.0013541
# Epoch: 480 Train loss: 0.33934 Validation loss: 0.00020745
# Epoch: 481 Train loss: 0.41675 Validation loss: 0.00035432
# Epoch: 482 Train loss: 0.41498 Validation loss: 0.0046404
# Epoch: 483 Train loss: 0.36903 Validation loss: 0.0021841
# Epoch: 484 Train loss: 0.30707 Validation loss: 0.00049108
# Epoch: 485 Train loss: 0.28644 Validation loss: 0.0010412
# Epoch: 486 Train loss: 0.29107 Validation loss: 0.0025994
# Epoch: 487 Train loss: 0.26811 Validation loss: 0.0012337
# Epoch: 488 Train loss: 0.35924 Validation loss: 0.0032769
# Epoch: 489 Train loss: 0.31101 Validation loss: 0.0016443
# Epoch: 490 Train loss: 0.29459 Validation loss: 0.00090072
# Epoch: 491 Train loss: 0.38694 Validation loss: 0.0019581
# Epoch: 492 Train loss: 0.35204 Validation loss: 0.0020946
# Epoch: 493 Train loss: 0.34864 Validation loss: 0.00088062
# Epoch: 494 Train loss: 0.40218 Validation loss: 0.0016603
# Epoch: 495 Train loss: 0.42445 Validation loss: 0.0012049
# Epoch: 496 Train loss: 0.40456 Validation loss: 0.0024688
# Epoch: 497 Train loss: 0.60546 Validation loss: 0.003933
# Epoch: 498 Train loss: 0.39711 Validation loss: 0.0014799
# Epoch: 499 Train loss: 0.50721 Validation loss: 0.0027306

# %% [markdown]
# During the training of the regularized model we can already notice, that, although there is still a difference between training and validation loss, the validation loss decreases as the training loss dreases. The effect of the regularization becomes even more evident if we plot the predictions of the regularized model and the overfitting model.

# %%
""" We now want to plot the prediction of the regularized and unregularized big model. """

y_pred = tf.reshape(tf.map_fn(big_reg_mdl, x), shape=[N_samples,])# Predict with "big_reg_mdl" on "x"
y_pred_overfit = tf.reshape(tf.map_fn(big_mdl, x), shape=[N_samples,])# Predict with "reg_mdl" on "x"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.plot(x, y_pred_overfit.numpy())
plt.legend(["Target", "Regularization", "No regularization", "Training samples"])
plt.show()

# %% [markdown]
# The model with regularization seems to follow the overall trend of the data, while the model without any regularization very precisely fits the training samples. This is espacilly evident in the interval $\left[0,0.5\right]$, where the prediction of the unregularized model shows an oscillating behavior. Such oscillations are however not present in the ground truth and therefore undesirable. The regularized model on the other hand is not as flexible as the unregularized model and therefore does not fit the target function well in the interval $\left[2.25, 3.0\right]$.
#
# ## Conclusion
# In this exercise we revisited the mathematical background for a simple regression task and covered it's practical implementation in Tensorflow 2. We also explored the phenomenon of overfitting and derived different regularizations from a probabilistic perspective. This exercise covers a very simple task with a very basic neural architecture and is intended as a primer for the second part of the regression exercise, which is dealing with a bigger and more realistic problem. In this second part we will consider the problem of estimating the age of a person from a potrait picture.
